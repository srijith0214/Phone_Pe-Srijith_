# %%
# !git clone https://github.com/PhonePe/pulse.git
# Out:
# fatal: destination path 'pulse' already exists and is not an empty directory.

# %% [markdown]
# # Aggregated Transaction data India

# %%
import os
path="/content/pulse/data/aggregated/transaction/country/india/"
Agg_India_list=os.listdir(path)
Agg_India_list.remove('state')
Agg_India_list
# Out:
# ['2023', '2018', '2022', '2021', '2020', '2019', '2024']

# %%
# Required libraries
import pandas as pd
import json

# Initialize dictionary to store transaction data for India (aggregated at country level)
cli = {
    'Year': [],
    'Quater': [],
    'Transacion_type': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Use the list of years from the India-level aggregated data
Agg_yr = Agg_India_list  # Make sure Agg_India_list is defined earlier

# Loop through each year folder
for i in Agg_India_list:
    p_i = path + i + "/"  # Path to the year folder
    Agg_qtr = os.listdir(p_i)  # List of quarter JSON files

    # Loop through each quarter JSON file
    for j in Agg_qtr:
        path_j = p_i + j  # Full path to the JSON file

        # Open and load the JSON data
        with open(path_j, 'r') as Data:
            D = json.load(Data)

            # Extract transaction data
            for z in D['data']['transactionData']:
                Name = z['name']
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']

                # Append extracted data to the dictionary
                cli['Transacion_type'].append(Name)
                cli['Transacion_count'].append(count)
                cli['Transacion_amount'].append(amount)
                cli['Year'].append(i)
                cli['Quater'].append(int(j.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Agg_Ind = pd.DataFrame(cli)

# %% [markdown]
# # Aggregated Transaction data India state

# %%
# Required libraries for the program
# (Make sure to import these before running the code)
# import os
# import json
# import pandas as pd

# Define the path to the transaction data by state
path = "/content/pulse/data/aggregated/transaction/country/india/state/"

# Get the list of states available in the dataset
Agg_state_list = os.listdir(path)
# Agg_state_list now contains all state folders

# Initialize dictionary to store transaction data
clm = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Transacion_type': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Loop through each state folder
for i in Agg_state_list:
    p_i = path + i + "/"  # Path to the state folder
    Agg_yr = os.listdir(p_i)  # List of years available for the state

    # Loop through each year folder
    for j in Agg_yr:
        p_j = p_i + j + "/"  # Path to the year folder
        Agg_yr_list = os.listdir(p_j)  # List of quarter JSON files

        # Loop through each quarter JSON file
        for k in Agg_yr_list:
            p_k = p_j + k  # Full path to the JSON file

            # Open and load the JSON data
            with open(p_k, 'r') as Data:
                D = json.load(Data)

                # Extract transaction data from the JSON
                for z in D['data']['transactionData']:
                    Name = z['name']
                    count = z['paymentInstruments'][0]['count']
                    amount = z['paymentInstruments'][0]['amount']

                    # Append extracted data to the dictionary
                    clm['Transacion_type'].append(Name)
                    clm['Transacion_count'].append(count)
                    clm['Transacion_amount'].append(amount)
                    clm['State'].append(i)
                    clm['Year'].append(j)
                    clm['Quater'].append(int(k.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Agg_Trans = pd.DataFrame(clm)

# %% [markdown]
# # Aggregated User State

# %%
import os
import json
import pandas as pd

path = "/content/pulse/data/aggregated/user/country/india/state/"
Agg_user_list = os.listdir(path)

Agg_user_state = {
    'State': [], 'Year': [], 'Quater': [],
    'registeredUsers': [], 'appOpens': []
}

Users_by_devices = {
    'State': [], 'Year': [], 'Quater': [],
    'Brand': [], 'Brand_count': [], 'Brand_percentage': []
}

for i in Agg_user_list:
    p_i = path + i + "/"
    Agg_yr = os.listdir(p_i)

    for j in Agg_yr:
        p_j = p_i + j + "/"
        Agg_yr_list = os.listdir(p_j)

        for k in Agg_yr_list:
            p_k = p_j + k

            try:
                with open(p_k, 'r') as Data:
                    D = json.load(Data)

                    # Extract aggregated data
                    registeredUsers = D['data']['aggregated'].get('registeredUsers')
                    appOpens = D['data']['aggregated'].get('appOpens')

                    Agg_user_state['registeredUsers'].append(registeredUsers)
                    Agg_user_state['appOpens'].append(appOpens)
                    Agg_user_state['State'].append(i)
                    Agg_user_state['Year'].append(j)
                    Agg_user_state['Quater'].append(int(k.strip('.json')))

                    # Extract usersByDevice only if it's a list
                    usersByDevice = D['data'].get('usersByDevice')
                    if isinstance(usersByDevice, list):
                        for device in usersByDevice:
                            Brand = device.get('brand')
                            Brand_count = device.get('count')
                            Brand_percentage = device.get('percentage')

                            Users_by_devices['Brand'].append(Brand)
                            Users_by_devices['Brand_count'].append(Brand_count)
                            Users_by_devices['Brand_percentage'].append(Brand_percentage)
                            Users_by_devices['State'].append(i)
                            Users_by_devices['Year'].append(j)
                            Users_by_devices['Quater'].append(int(k.strip('.json')))

            except Exception as e:
                print(f"Error processing file {p_k}: {e}")

# Convert to DataFrames
Agg_User_State = pd.DataFrame(Agg_user_state)
Users_by_Devices = pd.DataFrame(Users_by_devices)

# Optional: display or save the DataFrames
# print(Agg_User_State)
# print(Users_by_Devices)

# %% [markdown]
# # Aggregated User India

# %%
# Define the path to the aggregated user data for India
path = "/content/pulse/data/aggregated/user/country/india/"

# List all items in the directory and remove 'state' as it's not needed
Agg_India_user = os.listdir(path)
Agg_India_user.remove('state')

# Initialize dictionary to store aggregated user data
Agg_user_Ind = {
    'Year': [],
    'Quater': [],
    'registeredUsers': [],
    'appOpens': []
}

# Initialize dictionary to store user device data
Users_by_devices = {
    'Year': [],
    'Quater': [],
    'Brand': [],
    'Brand_count': [],
    'Brand_percentage': []
}

# Loop through each year folder in the India user data
for i in Agg_India_user:
    p_i = path + i + "/"  # Construct path to the year folder
    Agg_user = os.listdir(p_i)  # List all JSON files (quarters) in the year folder

    # Loop through each quarter JSON file
    for j in Agg_user:
        path_j = p_i + j  # Full path to the JSON file

        try:
            # Open and load the JSON data
            with open(path_j, 'r') as Data:
                D = json.load(Data)

                # Extract registered users and app opens
                registeredUsers = D['data']['aggregated'].get('registeredUsers')
                appOpens = D['data']['aggregated'].get('appOpens')

                # Append data to the aggregated user dictionary
                Agg_user_Ind['registeredUsers'].append(registeredUsers)
                Agg_user_Ind['appOpens'].append(appOpens)
                Agg_user_Ind['Year'].append(i)
                Agg_user_Ind['Quater'].append(int(j.strip('.json')))

                # Extract device usage data if available
                usersByDevice = D['data'].get('usersByDevice')
                if isinstance(usersByDevice, list):
                    for device in usersByDevice:
                        Brand = device.get('brand')
                        Brand_count = device.get('count')
                        Brand_percentage = device.get('percentage')

                        # Append device data to the device dictionary
                        Users_by_devices['Brand'].append(Brand)
                        Users_by_devices['Brand_count'].append(Brand_count)
                        Users_by_devices['Brand_percentage'].append(Brand_percentage)
                        Users_by_devices['Year'].append(i)
                        Users_by_devices['Quater'].append(int(j.strip('.json')))
        except Exception as e:
            # Print error message if file processing fails
            print(f"Error processing file {path_j}: {e}")

# Convert dictionaries to pandas DataFrames for further analysis
Agg_Ind_User = pd.DataFrame(Agg_user_Ind)
Users_by_devices = pd.DataFrame(Users_by_devices)

# %% [markdown]
# # Aggregated Insurance Data

# %%
path="/content/pulse/data/aggregated/insurance/country/india/"
Agg_India_list=os.listdir(path)
Agg_India_list.remove('state')
Agg_India_list
Agg_Ind_Ins = {
    'Year': [],
    'Quater': [],
    'Transacion_type': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Use the list of years from the India-level aggregated data
Agg_yr = Agg_India_list  # Make sure Agg_India_list is defined earlier

# Loop through each year folder
for i in Agg_India_list:
    p_i = path + i + "/"  # Path to the year folder
    Agg_qtr = os.listdir(p_i)  # List of quarter JSON files

    # Loop through each quarter JSON file
    for j in Agg_qtr:
        path_j = p_i + j  # Full path to the JSON file

        # Open and load the JSON data
        with open(path_j, 'r') as Data:
            D = json.load(Data)

            # Extract transaction data
            for z in D['data']['transactionData']:
                Name = z['name']
                count = z['paymentInstruments'][0]['count']
                amount = z['paymentInstruments'][0]['amount']

                # Append extracted data to the dictionary
                Agg_Ind_Ins['Transacion_type'].append(Name)
                Agg_Ind_Ins['Transacion_count'].append(count)
                Agg_Ind_Ins['Transacion_amount'].append(amount)
                Agg_Ind_Ins['Year'].append(i)
                Agg_Ind_Ins['Quater'].append(int(j.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Agg_Ind_Insurance = pd.DataFrame(Agg_Ind_Ins)
Agg_Ind_Insurance
# Out:
#     Year  Quater Transacion_type  Transacion_count  Transacion_amount
# 0   2023       1       Insurance            923173       1.408801e+09
# 1   2023       2       Insurance            893850       1.347400e+09
# 2   2023       3       Insurance           1010211       1.445235e+09
# 3   2023       4       Insurance           1159063       1.855300e+09
# 4   2022       1       Insurance            617606       8.874472e+08
# 5   2022       2       Insurance            630758       8.570348e+08
# 6   2022       3       Insurance            806491       1.054718e+09
# 7   2022       4       Insurance           1035364       1.439763e+09
# 8   2021       1       Insurance            318119       2.063070e+08
# 9   2021       2       Insurance            363989       2.950667e+08
# 10  2021       3       Insurance            374867       3.424034e+08
# 11  2021       4       Insurance            526327       6.554319e+08
# 12  2020       2       Insurance            185348       3.373217e+07
# 13  2020       3       Insurance            354284       8.949508e+07
# 14  2020       4       Insurance            248626       1.709799e+08
# 15  2024       1       Insurance           1273789       1.931956e+09
# 16  2024       2       Insurance           1105041       1.759628e+09
# 17  2024       3       Insurance           1213629       1.941266e+09
# 18  2024       4       Insurance           1475429       2.293956e+09

# %% [markdown]
# #Aggregated Insurance State data

# %%
# Required libraries for the program
# (Make sure to import these before running the code)
# import os
# import json
# import pandas as pd

# Define the path to the transaction data by state
path = "/content/pulse/data/aggregated/insurance/country/india/state/"

# Get the list of states available in the dataset
Agg_state_list = os.listdir(path)
# Agg_state_list now contains all state folders

# Initialize dictionary to store transaction data
Agg_state_Ins = {
    'State': [],
    'Year': [],
    'Quater': [],
    'Transacion_type': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Loop through each state folder
for i in Agg_state_list:
    p_i = path + i + "/"  # Path to the state folder
    Agg_yr = os.listdir(p_i)  # List of years available for the state

    # Loop through each year folder
    for j in Agg_yr:
        p_j = p_i + j + "/"  # Path to the year folder
        Agg_yr_list = os.listdir(p_j)  # List of quarter JSON files

        # Loop through each quarter JSON file
        for k in Agg_yr_list:
            p_k = p_j + k  # Full path to the JSON file

            # Open and load the JSON data
            with open(p_k, 'r') as Data:
                D = json.load(Data)

                # Extract transaction data from the JSON
                for z in D['data']['transactionData']:
                    Name = z['name']
                    count = z['paymentInstruments'][0]['count']
                    amount = z['paymentInstruments'][0]['amount']

                    # Append extracted data to the dictionary
                    Agg_state_Ins['Transacion_type'].append(Name)
                    Agg_state_Ins['Transacion_count'].append(count)
                    Agg_state_Ins['Transacion_amount'].append(amount)
                    Agg_state_Ins['State'].append(i)
                    Agg_state_Ins['Year'].append(j)
                    Agg_state_Ins['Quater'].append(int(k.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Agg_Trans = pd.DataFrame(clm)

# %% [markdown]
# # Top Insurance Data for States

# %%
# Required libraries for the program
# (Make sure to import these before running the code)
# import os
# import json
# import pandas as pd

# Define the path to the transaction data by state
path = "/content/pulse/data/top/insurance/country/india/state/"

# Get the list of states available in the dataset
Top_state_list = os.listdir(path)
# Agg_state_list now contains all state folders

# Initialize dictionary to store transaction data
Top_state_Ins = {
    'State': [],
    'Year': [],
    'Quater': [],
    'District_Name': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Loop through each state folder
for i in Top_state_list:
    p_i = path + i + "/"  # Path to the state folder
    Top_yr = os.listdir(p_i)  # List of years available for the state

    # Loop through each year folder
    for j in Top_yr:
        p_j = p_i + j + "/"  # Path to the year folder
        Top_yr_list = os.listdir(p_j)  # List of quarter JSON files

        # Loop through each quarter JSON file
        for k in Top_yr_list:
            p_k = p_j + k  # Full path to the JSON file
            # Open and load the JSON data
            with open(p_k, 'r') as Data:
                D = json.load(Data)

#                 # Extract transaction data from the JSON
                for z in D['data']['districts']:
                    Name = z['entityName']
                    count = z['metric'].get('count')
                    amount = z['metric'].get('amount')


                    # Append extracted data to the dictionary
                    Top_state_Ins['District_Name'].append(Name)
                    Top_state_Ins['Transacion_count'].append(count)
                    Top_state_Ins['Transacion_amount'].append(amount)
                    Top_state_Ins['State'].append(i)
                    Top_state_Ins['Year'].append(j)
                    Top_state_Ins['Quater'].append(int(k.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Top_Ins_Trans = pd.DataFrame(Top_state_Ins)

# %% [markdown]
# # Top insurance data for india

# %%
path="/content/pulse/data/top/insurance/country/india/"
Top_India_list=os.listdir(path)
Top_India_list.remove('state')
# Initialize dictionary to store transaction data for India (aggregated at country level)
Top_Ind_list = {
    'Year': [],
    'Quater': [],
    'State': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Use the list of years from the India-level aggregated data
top_Yr = Top_India_list  # Make sure Agg_India_list is defined earlier

# Loop through each year folder
for i in Agg_India_list:
    p_i = path + i + "/"  # Path to the year folder
    top_Qtr = os.listdir(p_i)  # List of quarter JSON files

    # Loop through each quarter JSON file
    for j in top_Qtr:
        path_j = p_i + j  # Full path to the JSON file

        # Open and load the JSON data
        with open(path_j, 'r') as Data:
            D = json.load(Data)
            # Extract transaction data
            for z in D['data']['states']:
                Name = z['entityName']
                count = z['metric'].get('count')
                amount = z['metric'].get('amount')

              # Append extracted data to the dictionary
                Top_Ind_list['State'].append(Name)
                Top_Ind_list['Transacion_count'].append(count)
                Top_Ind_list['Transacion_amount'].append(amount)
                Top_Ind_list['Year'].append(i)
                Top_Ind_list['Quater'].append(int(j.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Top_Ind_Inslist = pd.DataFrame(Top_Ind_list)

# %% [markdown]
# # Top transaction of India

# %%
path="/content/pulse/data/top/transaction/country/india/"
Top_India_list=os.listdir(path)
Top_India_list.remove('state')
# Initialize dictionary to store transaction data for India (aggregated at country level)
Top_Ind_list = {
    'Year': [],
    'Quater': [],
    'State': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Use the list of years from the India-level aggregated data
top_Yr = Top_India_list  # Make sure Agg_India_list is defined earlier

# Loop through each year folder
for i in Top_India_list:
    p_i = path + i + "/"  # Path to the year folder
    top_Qtr = os.listdir(p_i)  # List of quarter JSON files

    # Loop through each quarter JSON file
    for j in top_Qtr:
        path_j = p_i + j  # Full path to the JSON file

        # Open and load the JSON data
        with open(path_j, 'r') as Data:
            D = json.load(Data)
            # Extract transaction data
            for z in D['data']['states']:
                Name = z['entityName']
                count = z['metric'].get('count')
                amount = z['metric'].get('amount')

              # Append extracted data to the dictionary
                Top_Ind_list['State'].append(Name)
                Top_Ind_list['Transacion_count'].append(count)
                Top_Ind_list['Transacion_amount'].append(amount)
                Top_Ind_list['Year'].append(i)
                Top_Ind_list['Quater'].append(int(j.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Top_Ind_Inslist = pd.DataFrame(Top_Ind_list)

# %% [markdown]
# # Top Transaction list of state

# %%
# Required libraries for the program
# (Make sure to import these before running the code)
# import os
# import json
# import pandas as pd

# Define the path to the transaction data by state
path = "/content/pulse/data/top/transaction/country/india/state/"

# Get the list of states available in the dataset
Top_state_list = os.listdir(path)
# Agg_state_list now contains all state folders

# Initialize dictionary to store transaction data
Top_state_Ins = {
    'State': [],
    'Year': [],
    'Quater': [],
    'District_Name': [],
    'Transacion_count': [],
    'Transacion_amount': []
}

# Loop through each state folder
for i in Top_state_list:
    p_i = path + i + "/"  # Path to the state folder
    Top_yr = os.listdir(p_i)  # List of years available for the state

    # Loop through each year folder
    for j in Top_yr:
        p_j = p_i + j + "/"  # Path to the year folder
        Top_yr_list = os.listdir(p_j)  # List of quarter JSON files

        # Loop through each quarter JSON file
        for k in Top_yr_list:
            p_k = p_j + k  # Full path to the JSON file
            # Open and load the JSON data
            with open(p_k, 'r') as Data:
                D = json.load(Data)

#                 # Extract transaction data from the JSON
                for z in D['data']['districts']:
                    Name = z['entityName']
                    count = z['metric'].get('count')
                    amount = z['metric'].get('amount')


                    # Append extracted data to the dictionary
                    Top_state_Ins['District_Name'].append(Name)
                    Top_state_Ins['Transacion_count'].append(count)
                    Top_state_Ins['Transacion_amount'].append(amount)
                    Top_state_Ins['State'].append(i)
                    Top_state_Ins['Year'].append(j)
                    Top_state_Ins['Quater'].append(int(k.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Top_Ins_Trans = pd.DataFrame(Top_state_Ins)

# %% [markdown]
# # Registered Users in India

# %%
path="/content/pulse/data/top/user/country/india/"
user_India_list=os.listdir(path)
user_India_list.remove('state')
# Initialize dictionary to store transaction data for India (aggregated at country level)
user_list_bystate = {
    'Year': [],
    'Quater': [],
    'State': [],
    'registeredUsers': []
}
user_list_bypincode = {
    'Year': [],
    'Quater': [],
    'PinCode': [],
    'registeredUsers': []
}

# Use the list of years from the India-level aggregated data
# top_Yr = Top_India_list  # Make sure Agg_India_list is defined earlier

# Loop through each year folder
for i in user_India_list:
    p_i = path + i + "/"  # Path to the year folder
    top_Qtr = os.listdir(p_i)  # List of quarter JSON files

    # Loop through each quarter JSON file
    for j in top_Qtr:
        path_j = p_i + j  # Full path to the JSON file

        # Open and load the JSON data
        with open(path_j, 'r') as Data:
            D = json.load(Data)
            # Extract transaction data

            for z in D['data']['states']:
                Name = z['name']
                registeredUsers = z['registeredUsers']

              # Append extracted data to the dictionary
                user_list_bystate['State'].append(Name)
                user_list_bystate['registeredUsers'].append(registeredUsers)
                user_list_bystate['Year'].append(i)
                user_list_bystate['Quater'].append(int(j.strip('.json')))

            for z in D['data']['pincodes']:
                Name = z['name']
                registeredUsers = z['registeredUsers']

              # Append extracted data to the dictionary
                user_list_bypincode['PinCode'].append(Name)
                user_list_bypincode['registeredUsers'].append(registeredUsers)
                user_list_bypincode['Year'].append(i)
                user_list_bypincode['Quater'].append(int(j.strip('.json')))

# Convert the dictionary to a pandas DataFrame
user_List_bystate = pd.DataFrame(user_list_bystate)
user_List_bypincode = pd.DataFrame(user_list_bypincode)

# %% [markdown]
# # Registered users in state

# %%
# Required libraries for the program
# (Make sure to import these before running the code)
# import os
# import json
# import pandas as pd

# Define the path to the transaction data by state
path = "/content/pulse/data/top/user/country/india/state/"

# Get the list of states available in the dataset
Top_state_list = os.listdir(path)
# Agg_state_list now contains all state folders

# Initialize dictionary to store transaction data
Top_state_Ins = {
    'State': [],
    'Year': [],
    'Quater': [],
    'District_Name': [],
    'registeredUsers': [],

}

# Loop through each state folder
for i in Top_state_list:
    p_i = path + i + "/"  # Path to the state folder
    Top_yr = os.listdir(p_i)  # List of years available for the state

    # Loop through each year folder
    for j in Top_yr:
        p_j = p_i + j + "/"  # Path to the year folder
        Top_yr_list = os.listdir(p_j)  # List of quarter JSON files

        # Loop through each quarter JSON file
        for k in Top_yr_list:
            p_k = p_j + k  # Full path to the JSON file
            # Open and load the JSON data
            with open(p_k, 'r') as Data:
                D = json.load(Data)

#                 # Extract transaction data from the JSON
                for z in D['data']['districts']:
                    Name = z['name']
                    registeredUsers = z['registeredUsers']



                    # Append extracted data to the dictionary
                    Top_state_Ins['District_Name'].append(Name)
                    Top_state_Ins['registeredUsers'].append(registeredUsers)
                    Top_state_Ins['State'].append(i)
                    Top_state_Ins['Year'].append(j)
                    Top_state_Ins['Quater'].append(int(k.strip('.json')))

# Convert the dictionary to a pandas DataFrame
Top_Ins_Trans = pd.DataFrame(Top_state_Ins)
# Out:
# {'name': 'east', 'registeredUsers': 145199}
# {'name': 'south', 'registeredUsers': 52942}
# {'name': 'west', 'registeredUsers': 32945}
# {'name': 'north', 'registeredUsers': 21354}
# {'name': 'east', 'registeredUsers': 150852}
# {'name': 'south', 'registeredUsers': 55158}
# {'name': 'west', 'registeredUsers': 34427}
# {'name': 'north', 'registeredUsers': 22291}
# {'name': 'east', 'registeredUsers': 156600}
# {'name': 'south', 'registeredUsers': 57259}
# {'name': 'west', 'registeredUsers': 35808}
# {'name': 'north', 'registeredUsers': 23162}
# {'name': 'east', 'registeredUsers': 162011}
# {'name': 'south', 'registeredUsers': 59357}
# {'name': 'west', 'registeredUsers': 37183}
# {'name': 'north', 'registeredUsers': 24024}
# {'name': 'east', 'registeredUsers': 12749}
# {'name': 'south', 'registeredUsers': 3679}
# {'name': 'west', 'registeredUsers': 2048}
# {'name': 'north', 'registeredUsers': 1575}
# {'name': 'east', 'registeredUsers': 17767}
# {'name': 'south', 'registeredUsers': 5147}
# {'name': 'west', 'registeredUsers': 2868}
# {'name': 'north', 'registeredUsers': 2315}
# {'name': 'east', 'registeredUsers': 23460}
# {'name': 'south', 'registeredUsers': 6943}
# {'name': 'west', 'registeredUsers': 4042}
# {'name': 'north', 'registeredUsers': 3192}
# {'name': 'east', 'registeredUsers': 29948}
# {'name': 'south', 'registeredUsers': 8992}
# {'name': 'west', 'registeredUsers': 5328}
# {'name': 'north', 'registeredUsers': 4270}
# {'name': 'east', 'registeredUsers': 120360}
# {'name': 'south', 'registeredUsers': 43881}
# {'name': 'west', 'registeredUsers': 27594}
# {'name': 'north', 'registeredUsers': 17781}
# {'name': 'east', 'registeredUsers': 126666}
# {'name': 'south', 'registeredUsers': 46351}
# {'name': 'west', 'registeredUsers': 29184}
# {'name': 'north', 'registeredUsers': 18793}
# {'name': 'east', 'registeredUsers': 133152}
# {'name': 'south', 'registeredUsers': 48673}
# {'name': 'west', 'registeredUsers': 30513}
# {'name': 'north', 'registeredUsers': 19687}
# {'name': 'east', 'registeredUsers': 139175}
# {'name': 'south', 'registeredUsers': 50716}
# {'name': 'west', 'registeredUsers': 31605}
# {'name': 'north', 'registeredUsers': 20472}
# {'name': 'east', 'registeredUsers': 92502}
# {'name': 'south', 'registeredUsers': 33490}
# {'name': 'west', 'registeredUsers': 20769}
# {'name': 'north', 'registeredUsers': 13452}
# {'name': 'east', 'registeredUsers': 99077}
# {'name': 'south', 'registeredUsers': 35900}
# {'name': 'west', 'registeredUsers': 22352}
# {'name': 'north', 'registeredUsers': 14411}
# {'name': 'east', 'registeredUsers': 106352}
# {'name': 'south', 'registeredUsers': 38616}
# {'name': 'west', 'registeredUsers': 24132}
# {'name': 'north', 'registeredUsers': 15593}
# {'name': 'east', 'registeredUsers': 113537}
# {'name': 'south', 'registeredUsers': 41311}
# {'name': 'west', 'registeredUsers': 25834}
# {'name': 'north', 'registeredUsers': 16725}
# {'name': 'east', 'registeredUsers': 61820}
# {'name': 'south', 'registeredUsers': 21043}
# {'name': 'west', 'registeredUsers': 12746}
# {'name': 'north', 'registeredUsers': 9022}
# {'name': 'east', 'registeredUsers': 69829}
# {'name': 'south', 'registeredUsers': 24768}
# {'name': 'west', 'registeredUsers': 15082}
# {'name': 'north', 'registeredUsers': 10242}
# {'name': 'east', 'registeredUsers': 78018}
# {'name': 'south', 'registeredUsers': 28038}
# {'name': 'west', 'registeredUsers': 17400}
# {'name': 'north', 'registeredUsers': 11317}
# {'name': 'east', 'registeredUsers': 85770}
# {'name': 'south', 'registeredUsers': 31055}
# {'name': 'west', 'registeredUsers': 19217}
# {'name': 'north', 'registeredUsers': 12501}
# {'name': 'east', 'registeredUsers': 36124}
# {'name': 'south', 'registeredUsers': 11031}
# {'name': 'west', 'registeredUsers': 6479}
# {'name': 'north', 'registeredUsers': 5322}
# {'name': 'east', 'registeredUsers': 43048}
# {'name': 'south', 'registeredUsers': 13547}
# {'name': 'west', 'registeredUsers': 8064}
# {'name': 'north', 'registeredUsers': 6340}
# {'name': 'east', 'registeredUsers': 49404}
# {'name': 'south', 'registeredUsers': 16016}
# {'name': 'west', 'registeredUsers': 9481}
# {'name': 'north', 'registeredUsers': 7227}
# {'name': 'east', 'registeredUsers': 55340}
# {'name': 'south', 'registeredUsers': 18461}
# {'name': 'west', 'registeredUsers': 11078}
# {'name': 'north', 'registeredUsers': 8093}
# {'name': 'east', 'registeredUsers': 168229}
# {'name': 'south', 'registeredUsers': 61782}
# {'name': 'west', 'registeredUsers': 38748}
# {'name': 'north', 'registeredUsers': 25062}
# {'name': 'east', 'registeredUsers': 174348}
# {'name': 'south', 'registeredUsers': 64133}
# {'name': 'west', 'registeredUsers': 40197}
# {'name': 'north', 'registeredUsers': 25972}
# {'name': 'gangtok', 'registeredUsers': 140362}
# {'name': 'namchi', 'registeredUsers': 56951}
# {'name': 'pakyong', 'registeredUsers': 50399}
# {'name': 'mangan', 'registeredUsers': 24207}
# {'name': 'gyalshing', 'registeredUsers': 23625}
# {'name': 'soreng', 'registeredUsers': 16767}
# {'name': 'gangtok', 'registeredUsers': 143928}
# {'name': 'namchi', 'registeredUsers': 58886}
# {'name': 'pakyong', 'registeredUsers': 51773}
# {'name': 'gyalshing', 'registeredUsers': 24563}
# {'name': 'mangan', 'registeredUsers': 24321}
# {'name': 'soreng', 'registeredUsers': 17277}
# {'name': 'puducherry', 'registeredUsers': 455449}
# {'name': 'karaikal', 'registeredUsers': 53685}
# {'name': 'yanam', 'registeredUsers': 20481}
# {'name': 'mahe', 'registeredUsers': 14204}
# {'name': 'puducherry', 'registeredUsers': 472714}
# {'name': 'karaikal', 'registeredUsers': 55776}
# {'name': 'yanam', 'registeredUsers': 21261}
# {'name': 'mahe', 'registeredUsers': 14680}
# {'name': 'puducherry', 'registeredUsers': 491130}
# {'name': 'karaikal', 'registeredUsers': 58040}
# {'name': 'yanam', 'registeredUsers': 22161}
# {'name': 'mahe', 'registeredUsers': 15219}
# {'name': 'puducherry', 'registeredUsers': 508901}
# {'name': 'karaikal', 'registeredUsers': 60186}
# {'name': 'yanam', 'registeredUsers': 23033}
# {'name': 'mahe', 'registeredUsers': 15718}
# {'name': 'puducherry', 'registeredUsers': 42117}
# {'name': 'karaikal', 'registeredUsers': 3628}
# {'name': 'yanam', 'registeredUsers': 2500}
# {'name': 'mahe', 'registeredUsers': 1073}
# {'name': 'puducherry', 'registeredUsers': 55513}
# {'name': 'karaikal', 'registeredUsers': 5393}
# {'name': 'yanam', 'registeredUsers': 3232}
# {'name': 'mahe', 'registeredUsers': 1442}
# {'name': 'puducherry', 'registeredUsers': 68634}
# {'name': 'karaikal', 'registeredUsers': 7174}
# {'name': 'yanam', 'registeredUsers': 3926}
# {'name': 'mahe', 'registeredUsers': 1812}
# {'name': 'puducherry', 'registeredUsers': 92629}
# {'name': 'karaikal', 'registeredUsers': 9578}
# {'name': 'yanam', 'registeredUsers': 4901}
# {'name': 'mahe', 'registeredUsers': 2386}
# {'name': 'puducherry', 'registeredUsers': 375238}
# {'name': 'karaikal', 'registeredUsers': 44201}
# {'name': 'yanam', 'registeredUsers': 16747}
# {'name': 'mahe', 'registeredUsers': 11865}
# {'name': 'puducherry', 'registeredUsers': 394977}
# {'name': 'karaikal', 'registeredUsers': 46573}
# {'name': 'yanam', 'registeredUsers': 17644}
# {'name': 'mahe', 'registeredUsers': 12469}
# {'name': 'puducherry', 'registeredUsers': 415847}
# {'name': 'karaikal', 'registeredUsers': 49034}
# {'name': 'yanam', 'registeredUsers': 18606}
# {'name': 'mahe', 'registeredUsers': 13083}
# {'name': 'puducherry', 'registeredUsers': 436067}
# {'name': 'karaikal', 'registeredUsers': 51364}
# {'name': 'yanam', 'registeredUsers': 19579}
# {'name': 'mahe', 'registeredUsers': 13639}
# {'name': 'puducherry', 'registeredUsers': 290107}
# {'name': 'karaikal', 'registeredUsers': 33876}
# {'name': 'yanam', 'registeredUsers': 13005}
# {'name': 'mahe', 'registeredUsers': 9291}
# {'name': 'puducherry', 'registeredUsers': 309892}
# {'name': 'karaikal', 'registeredUsers': 36328}
# {'name': 'yanam', 'registeredUsers': 13854}
# {'name': 'mahe', 'registeredUsers': 9887}
# {'name': 'puducherry', 'registeredUsers': 332193}
# {'name': 'karaikal', 'registeredUsers': 39011}
# {'name': 'yanam', 'registeredUsers': 14823}
# {'name': 'mahe', 'registeredUsers': 10582}
# {'name': 'puducherry', 'registeredUsers': 354425}
# {'name': 'karaikal', 'registeredUsers': 41695}
# {'name': 'yanam', 'registeredUsers': 15809}
# {'name': 'mahe', 'registeredUsers': 11238}
# {'name': 'puducherry', 'registeredUsers': 195398}
# {'name': 'karaikal', 'registeredUsers': 20775}
# {'name': 'yanam', 'registeredUsers': 9266}
# {'name': 'mahe', 'registeredUsers': 5469}
# {'name': 'puducherry', 'registeredUsers': 215429}
# {'name': 'karaikal', 'registeredUsers': 23612}
# {'name': 'yanam', 'registeredUsers': 10164}
# {'name': 'mahe', 'registeredUsers': 6395}
# {'name': 'puducherry', 'registeredUsers': 239707}
# {'name': 'karaikal', 'registeredUsers': 26910}
# {'name': 'yanam', 'registeredUsers': 11054}
# {'name': 'mahe', 'registeredUsers': 7502}
# {'name': 'puducherry', 'registeredUsers': 267946}
# {'name': 'karaikal', 'registeredUsers': 30982}
# {'name': 'yanam', 'registeredUsers': 12131}
# {'name': 'mahe', 'registeredUsers': 8567}
# {'name': 'puducherry', 'registeredUsers': 112798}
# {'name': 'karaikal', 'registeredUsers': 11549}
# {'name': 'yanam', 'registeredUsers': 5814}
# {'name': 'mahe', 'registeredUsers': 2898}
# {'name': 'puducherry', 'registeredUsers': 132703}
# {'name': 'karaikal', 'registeredUsers': 13827}
# {'name': 'yanam', 'registeredUsers': 6485}
# {'name': 'mahe', 'registeredUsers': 3443}
# {'name': 'puducherry', 'registeredUsers': 150642}
# {'name': 'karaikal', 'registeredUsers': 15875}
# {'name': 'yanam', 'registeredUsers': 7342}
# {'name': 'mahe', 'registeredUsers': 4009}
# {'name': 'puducherry', 'registeredUsers': 173175}
# {'name': 'karaikal', 'registeredUsers': 18134}
# {'name': 'yanam', 'registeredUsers': 8287}
# {'name': 'mahe', 'registeredUsers': 4696}
# {'name': 'puducherry', 'registeredUsers': 528736}
# {'name': 'karaikal', 'registeredUsers': 62687}
# {'name': 'yanam', 'registeredUsers': 23967}
# {'name': 'mahe', 'registeredUsers': 16273}
# {'name': 'puducherry', 'registeredUsers': 548672}
# {'name': 'karaikal', 'registeredUsers': 65076}
# {'name': 'yanam', 'registeredUsers': 24917}
# {'name': 'mahe', 'registeredUsers': 16821}
# {'name': 'puducherry', 'registeredUsers': 511282}
# {'name': 'karaikal', 'registeredUsers': 73963}
# {'name': 'yanam', 'registeredUsers': 22351}
# {'name': 'mahe', 'registeredUsers': 21736}
# {'name': 'puducherry', 'registeredUsers': 524684}
# {'name': 'karaikal', 'registeredUsers': 76256}
# {'name': 'yanam', 'registeredUsers': 22823}
# {'name': 'mahe', 'registeredUsers': 22395}
# {'name': 'ludhiana', 'registeredUsers': 1807587}
# {'name': 'sas nagar', 'registeredUsers': 987246}
# {'name': 'amritsar', 'registeredUsers': 715172}
# {'name': 'jalandhar', 'registeredUsers': 677948}
# {'name': 'patiala', 'registeredUsers': 662760}
# {'name': 'bathinda', 'registeredUsers': 458473}
# {'name': 'fazilka', 'registeredUsers': 397546}
# {'name': 'sangrur', 'registeredUsers': 386728}
# {'name': 'hoshiarpur', 'registeredUsers': 330374}
# {'name': 'gurdaspur', 'registeredUsers': 296711}
# {'name': 'ludhiana', 'registeredUsers': 1883319}
# {'name': 'sas nagar', 'registeredUsers': 1024325}
# {'name': 'amritsar', 'registeredUsers': 742659}
# {'name': 'jalandhar', 'registeredUsers': 705082}
# {'name': 'patiala', 'registeredUsers': 688795}
# {'name': 'bathinda', 'registeredUsers': 477038}
# {'name': 'fazilka', 'registeredUsers': 414974}
# {'name': 'sangrur', 'registeredUsers': 402871}
# {'name': 'hoshiarpur', 'registeredUsers': 344428}
# {'name': 'gurdaspur', 'registeredUsers': 308841}
# {'name': 'ludhiana', 'registeredUsers': 1957125}
# {'name': 'sas nagar', 'registeredUsers': 1062990}
# {'name': 'amritsar', 'registeredUsers': 771321}
# {'name': 'jalandhar', 'registeredUsers': 732473}
# {'name': 'patiala', 'registeredUsers': 715678}
# {'name': 'bathinda', 'registeredUsers': 495871}
# {'name': 'fazilka', 'registeredUsers': 431814}
# {'name': 'sangrur', 'registeredUsers': 418793}
# {'name': 'hoshiarpur', 'registeredUsers': 358108}
# {'name': 'gurdaspur', 'registeredUsers': 320776}
# {'name': 'ludhiana', 'registeredUsers': 2030159}
# {'name': 'sas nagar', 'registeredUsers': 1099060}
# {'name': 'amritsar', 'registeredUsers': 798214}
# {'name': 'jalandhar', 'registeredUsers': 758342}
# {'name': 'patiala', 'registeredUsers': 740516}
# {'name': 'bathinda', 'registeredUsers': 513676}
# {'name': 'fazilka', 'registeredUsers': 447755}
# {'name': 'sangrur', 'registeredUsers': 433927}
# {'name': 'hoshiarpur', 'registeredUsers': 371220}
# {'name': 'gurdaspur', 'registeredUsers': 332236}
# {'name': 'ludhiana', 'registeredUsers': 168625}
# {'name': 'sas nagar', 'registeredUsers': 121113}
# {'name': 'patiala', 'registeredUsers': 66507}
# {'name': 'amritsar', 'registeredUsers': 59685}
# {'name': 'jalandhar', 'registeredUsers': 57808}
# {'name': 'bathinda', 'registeredUsers': 52466}
# {'name': 'fazilka', 'registeredUsers': 44823}
# {'name': 'sangrur', 'registeredUsers': 37485}
# {'name': 'hoshiarpur', 'registeredUsers': 25348}
# {'name': 'gurdaspur', 'registeredUsers': 21372}
# {'name': 'ludhiana', 'registeredUsers': 230404}
# {'name': 'sas nagar', 'registeredUsers': 161605}
# {'name': 'patiala', 'registeredUsers': 90123}
# {'name': 'amritsar', 'registeredUsers': 82735}
# {'name': 'jalandhar', 'registeredUsers': 79991}
# {'name': 'bathinda', 'registeredUsers': 70948}
# {'name': 'fazilka', 'registeredUsers': 60134}
# {'name': 'sangrur', 'registeredUsers': 50749}
# {'name': 'hoshiarpur', 'registeredUsers': 34576}
# {'name': 'gurdaspur', 'registeredUsers': 29910}
# {'name': 'ludhiana', 'registeredUsers': 296414}
# {'name': 'sas nagar', 'registeredUsers': 201458}
# {'name': 'patiala', 'registeredUsers': 113902}
# {'name': 'amritsar', 'registeredUsers': 108935}
# {'name': 'jalandhar', 'registeredUsers': 104824}
# {'name': 'bathinda', 'registeredUsers': 88508}
# {'name': 'fazilka', 'registeredUsers': 73785}
# {'name': 'sangrur', 'registeredUsers': 64978}
# {'name': 'hoshiarpur', 'registeredUsers': 45862}
# {'name': 'gurdaspur', 'registeredUsers': 39920}
# {'name': 'ludhiana', 'registeredUsers': 378237}
# {'name': 'sas nagar', 'registeredUsers': 250733}
# {'name': 'patiala', 'registeredUsers': 142989}
# {'name': 'amritsar', 'registeredUsers': 141933}
# {'name': 'jalandhar', 'registeredUsers': 135966}
# {'name': 'bathinda', 'registeredUsers': 109505}
# {'name': 'fazilka', 'registeredUsers': 89590}
# {'name': 'sangrur', 'registeredUsers': 82334}
# {'name': 'hoshiarpur', 'registeredUsers': 59684}
# {'name': 'gurdaspur', 'registeredUsers': 51644}
# {'name': 'ludhiana', 'registeredUsers': 1476288}
# {'name': 'sas nagar', 'registeredUsers': 817209}
# {'name': 'amritsar', 'registeredUsers': 593970}
# {'name': 'jalandhar', 'registeredUsers': 560393}
# {'name': 'patiala', 'registeredUsers': 550482}
# {'name': 'bathinda', 'registeredUsers': 378864}
# {'name': 'fazilka', 'registeredUsers': 327088}
# {'name': 'sangrur', 'registeredUsers': 321129}
# {'name': 'hoshiarpur', 'registeredUsers': 274004}
# {'name': 'gurdaspur', 'registeredUsers': 247179}
# {'name': 'ludhiana', 'registeredUsers': 1558996}
# {'name': 'sas nagar', 'registeredUsers': 859976}
# {'name': 'amritsar', 'registeredUsers': 625338}
# {'name': 'jalandhar', 'registeredUsers': 590791}
# {'name': 'patiala', 'registeredUsers': 579934}
# {'name': 'bathinda', 'registeredUsers': 399793}
# {'name': 'fazilka', 'registeredUsers': 345717}
# {'name': 'sangrur', 'registeredUsers': 338752}
# {'name': 'hoshiarpur', 'registeredUsers': 289259}
# {'name': 'gurdaspur', 'registeredUsers': 260611}
# {'name': 'ludhiana', 'registeredUsers': 1644780}
# {'name': 'sas nagar', 'registeredUsers': 904073}
# {'name': 'amritsar', 'registeredUsers': 656700}
# {'name': 'jalandhar', 'registeredUsers': 621327}
# {'name': 'patiala', 'registeredUsers': 608884}
# {'name': 'bathinda', 'registeredUsers': 420285}
# {'name': 'fazilka', 'registeredUsers': 363909}
# {'name': 'sangrur', 'registeredUsers': 355769}
# {'name': 'hoshiarpur', 'registeredUsers': 303683}
# {'name': 'gurdaspur', 'registeredUsers': 273518}
# {'name': 'ludhiana', 'registeredUsers': 1728119}
# {'name': 'sas nagar', 'registeredUsers': 946603}
# {'name': 'amritsar', 'registeredUsers': 686055}
# {'name': 'jalandhar', 'registeredUsers': 649918}
# {'name': 'patiala', 'registeredUsers': 635654}
# {'name': 'bathinda', 'registeredUsers': 439064}
# {'name': 'fazilka', 'registeredUsers': 380321}
# {'name': 'sangrur', 'registeredUsers': 370649}
# {'name': 'hoshiarpur', 'registeredUsers': 316389}
# {'name': 'gurdaspur', 'registeredUsers': 284591}
# {'name': 'ludhiana', 'registeredUsers': 1121835}
# {'name': 'sas nagar', 'registeredUsers': 631136}
# {'name': 'amritsar', 'registeredUsers': 456913}
# {'name': 'jalandhar', 'registeredUsers': 428704}
# {'name': 'patiala', 'registeredUsers': 421866}
# {'name': 'bathinda', 'registeredUsers': 288460}
# {'name': 'fazilka', 'registeredUsers': 247363}
# {'name': 'sangrur', 'registeredUsers': 243382}
# {'name': 'hoshiarpur', 'registeredUsers': 207567}
# {'name': 'gurdaspur', 'registeredUsers': 187933}
# {'name': 'ludhiana', 'registeredUsers': 1204126}
# {'name': 'sas nagar', 'registeredUsers': 675022}
# {'name': 'amritsar', 'registeredUsers': 489463}
# {'name': 'jalandhar', 'registeredUsers': 459789}
# {'name': 'patiala', 'registeredUsers': 452152}
# {'name': 'bathinda', 'registeredUsers': 309805}
# {'name': 'fazilka', 'registeredUsers': 265874}
# {'name': 'sangrur', 'registeredUsers': 261746}
# {'name': 'hoshiarpur', 'registeredUsers': 223227}
# {'name': 'gurdaspur', 'registeredUsers': 201976}
# {'name': 'ludhiana', 'registeredUsers': 1296796}
# {'name': 'sas nagar', 'registeredUsers': 723884}
# {'name': 'amritsar', 'registeredUsers': 525756}
# {'name': 'jalandhar', 'registeredUsers': 494582}
# {'name': 'patiala', 'registeredUsers': 486329}
# {'name': 'bathinda', 'registeredUsers': 333661}
# {'name': 'fazilka', 'registeredUsers': 287001}
# {'name': 'sangrur', 'registeredUsers': 282372}
# {'name': 'hoshiarpur', 'registeredUsers': 240996}
# {'name': 'gurdaspur', 'registeredUsers': 217927}
# {'name': 'ludhiana', 'registeredUsers': 1388951}
# {'name': 'sas nagar', 'registeredUsers': 772068}
# {'name': 'amritsar', 'registeredUsers': 560687}
# {'name': 'jalandhar', 'registeredUsers': 528440}
# {'name': 'patiala', 'registeredUsers': 519356}
# {'name': 'bathinda', 'registeredUsers': 356940}
# {'name': 'fazilka', 'registeredUsers': 307291}
# {'name': 'sangrur', 'registeredUsers': 302394}
# {'name': 'hoshiarpur', 'registeredUsers': 257735}
# {'name': 'gurdaspur', 'registeredUsers': 232798}
# {'name': 'ludhiana', 'registeredUsers': 756590}
# {'name': 'sas nagar', 'registeredUsers': 460416}
# {'name': 'amritsar', 'registeredUsers': 303767}
# {'name': 'patiala', 'registeredUsers': 287330}
# {'name': 'jalandhar', 'registeredUsers': 282191}
# {'name': 'bathinda', 'registeredUsers': 200425}
# {'name': 'fazilka', 'registeredUsers': 168714}
# {'name': 'sangrur', 'registeredUsers': 161513}
# {'name': 'hoshiarpur', 'registeredUsers': 129693}
# {'name': 'gurdaspur', 'registeredUsers': 116534}
# {'name': 'ludhiana', 'registeredUsers': 853140}
# {'name': 'sas nagar', 'registeredUsers': 498018}
# {'name': 'amritsar', 'registeredUsers': 343732}
# {'name': 'patiala', 'registeredUsers': 323801}
# {'name': 'jalandhar', 'registeredUsers': 320498}
# {'name': 'bathinda', 'registeredUsers': 222968}
# {'name': 'fazilka', 'registeredUsers': 188515}
# {'name': 'sangrur', 'registeredUsers': 183342}
# {'name': 'hoshiarpur', 'registeredUsers': 153462}
# {'name': 'gurdaspur', 'registeredUsers': 137571}
# {'name': 'ludhiana', 'registeredUsers': 944936}
# {'name': 'sas nagar', 'registeredUsers': 540527}
# {'name': 'amritsar', 'registeredUsers': 383166}
# {'name': 'jalandhar', 'registeredUsers': 359980}
# {'name': 'patiala', 'registeredUsers': 358126}
# {'name': 'bathinda', 'registeredUsers': 245674}
# {'name': 'fazilka', 'registeredUsers': 208929}
# {'name': 'sangrur', 'registeredUsers': 204491}
# {'name': 'hoshiarpur', 'registeredUsers': 173002}
# {'name': 'gurdaspur', 'registeredUsers': 155619}
# {'name': 'ludhiana', 'registeredUsers': 1037696}
# {'name': 'sas nagar', 'registeredUsers': 586500}
# {'name': 'amritsar', 'registeredUsers': 423283}
# {'name': 'jalandhar', 'registeredUsers': 396951}
# {'name': 'patiala', 'registeredUsers': 391658}
# {'name': 'bathinda', 'registeredUsers': 267808}
# {'name': 'fazilka', 'registeredUsers': 228837}
# {'name': 'sangrur', 'registeredUsers': 225211}
# {'name': 'hoshiarpur', 'registeredUsers': 191711}
# {'name': 'gurdaspur', 'registeredUsers': 173650}
# {'name': 'ludhiana', 'registeredUsers': 454370}
# {'name': 'sas nagar', 'registeredUsers': 298288}
# {'name': 'amritsar', 'registeredUsers': 171264}
# {'name': 'patiala', 'registeredUsers': 169872}
# {'name': 'jalandhar', 'registeredUsers': 164130}
# {'name': 'bathinda', 'registeredUsers': 128070}
# {'name': 'fazilka', 'registeredUsers': 104942}
# {'name': 'sangrur', 'registeredUsers': 97326}
# {'name': 'hoshiarpur', 'registeredUsers': 72128}
# {'name': 'gurdaspur', 'registeredUsers': 62502}
# {'name': 'ludhiana', 'registeredUsers': 528745}
# {'name': 'sas nagar', 'registeredUsers': 343153}
# {'name': 'amritsar', 'registeredUsers': 206517}
# {'name': 'patiala', 'registeredUsers': 199960}
# {'name': 'jalandhar', 'registeredUsers': 195283}
# {'name': 'bathinda', 'registeredUsers': 145282}
# {'name': 'fazilka', 'registeredUsers': 118707}
# {'name': 'sangrur', 'registeredUsers': 111996}
# {'name': 'hoshiarpur', 'registeredUsers': 86022}
# {'name': 'gurdaspur', 'registeredUsers': 75170}
# {'name': 'ludhiana', 'registeredUsers': 601479}
# {'name': 'sas nagar', 'registeredUsers': 385263}
# {'name': 'amritsar', 'registeredUsers': 238628}
# {'name': 'patiala', 'registeredUsers': 229488}
# {'name': 'jalandhar', 'registeredUsers': 225027}
# {'name': 'bathinda', 'registeredUsers': 162800}
# {'name': 'fazilka', 'registeredUsers': 132573}
# {'name': 'sangrur', 'registeredUsers': 127329}
# {'name': 'hoshiarpur', 'registeredUsers': 99272}
# {'name': 'gurdaspur', 'registeredUsers': 87043}
# {'name': 'ludhiana', 'registeredUsers': 671579}
# {'name': 'sas nagar', 'registeredUsers': 422041}
# {'name': 'amritsar', 'registeredUsers': 268663}
# {'name': 'patiala', 'registeredUsers': 256911}
# {'name': 'jalandhar', 'registeredUsers': 251259}
# {'name': 'bathinda', 'registeredUsers': 180722}
# {'name': 'fazilka', 'registeredUsers': 149868}
# {'name': 'sangrur', 'registeredUsers': 143162}
# {'name': 'hoshiarpur', 'registeredUsers': 113296}
# {'name': 'gurdaspur', 'registeredUsers': 100393}
# {'name': 'ludhiana', 'registeredUsers': 2111816}
# {'name': 'sas nagar', 'registeredUsers': 1140194}
# {'name': 'amritsar', 'registeredUsers': 828669}
# {'name': 'jalandhar', 'registeredUsers': 787722}
# {'name': 'patiala', 'registeredUsers': 768945}
# {'name': 'bathinda', 'registeredUsers': 534058}
# {'name': 'fazilka', 'registeredUsers': 465859}
# {'name': 'sangrur', 'registeredUsers': 451041}
# {'name': 'hoshiarpur', 'registeredUsers': 386238}
# {'name': 'gurdaspur', 'registeredUsers': 345175}
# {'name': 'ludhiana', 'registeredUsers': 2193835}
# {'name': 'sas nagar', 'registeredUsers': 1182293}
# {'name': 'amritsar', 'registeredUsers': 860199}
# {'name': 'jalandhar', 'registeredUsers': 817774}
# {'name': 'patiala', 'registeredUsers': 797912}
# {'name': 'bathinda', 'registeredUsers': 553994}
# {'name': 'fazilka', 'registeredUsers': 483712}
# {'name': 'sangrur', 'registeredUsers': 468298}
# {'name': 'hoshiarpur', 'registeredUsers': 401488}
# {'name': 'gurdaspur', 'registeredUsers': 358468}
# {'name': 'ludhiana', 'registeredUsers': 2288105}
# {'name': 'sas nagar', 'registeredUsers': 1248412}
# {'name': 'amritsar', 'registeredUsers': 932165}
# {'name': 'jalandhar', 'registeredUsers': 855160}
# {'name': 'patiala', 'registeredUsers': 756718}
# {'name': 'bathinda', 'registeredUsers': 509440}
# {'name': 'hoshiarpur', 'registeredUsers': 424706}
# {'name': 'fazilka', 'registeredUsers': 395249}
# {'name': 'gurdaspur', 'registeredUsers': 394383}
# {'name': 'sangrur', 'registeredUsers': 334195}
# {'name': 'ludhiana', 'registeredUsers': 2352294}
# {'name': 'sas nagar', 'registeredUsers': 1284134}
# {'name': 'amritsar', 'registeredUsers': 960254}
# {'name': 'jalandhar', 'registeredUsers': 880313}
# {'name': 'patiala', 'registeredUsers': 778895}
# {'name': 'bathinda', 'registeredUsers': 524150}
# {'name': 'hoshiarpur', 'registeredUsers': 438513}
# {'name': 'fazilka', 'registeredUsers': 407727}
# {'name': 'gurdaspur', 'registeredUsers': 407049}
# {'name': 'sangrur', 'registeredUsers': 344663}
# {'name': 'dimapur', 'registeredUsers': 152828}
# {'name': 'kohima', 'registeredUsers': 60269}
# {'name': 'mon', 'registeredUsers': 26501}
# {'name': 'mokokchung', 'registeredUsers': 25058}
# {'name': 'wokha', 'registeredUsers': 15357}
# {'name': 'tuensang', 'registeredUsers': 14523}
# {'name': 'phek', 'registeredUsers': 12359}
# {'name': 'zunheboto', 'registeredUsers': 9817}
# {'name': 'peren', 'registeredUsers': 7042}
# {'name': 'kiphire', 'registeredUsers': 6491}
# {'name': 'dimapur', 'registeredUsers': 159224}
# {'name': 'kohima', 'registeredUsers': 62890}
# {'name': 'mon', 'registeredUsers': 27813}
# {'name': 'mokokchung', 'registeredUsers': 26232}
# {'name': 'wokha', 'registeredUsers': 16076}
# {'name': 'tuensang', 'registeredUsers': 15272}
# {'name': 'phek', 'registeredUsers': 13007}
# {'name': 'zunheboto', 'registeredUsers': 10327}
# {'name': 'peren', 'registeredUsers': 7407}
# {'name': 'kiphire', 'registeredUsers': 6792}
# {'name': 'dimapur', 'registeredUsers': 165789}
# {'name': 'kohima', 'registeredUsers': 65492}
# {'name': 'mon', 'registeredUsers': 29096}
# {'name': 'mokokchung', 'registeredUsers': 27434}
# {'name': 'wokha', 'registeredUsers': 16792}
# {'name': 'tuensang', 'registeredUsers': 15941}
# {'name': 'phek', 'registeredUsers': 13632}
# {'name': 'zunheboto', 'registeredUsers': 10809}
# {'name': 'peren', 'registeredUsers': 7771}
# {'name': 'kiphire', 'registeredUsers': 7130}
# {'name': 'dimapur', 'registeredUsers': 172342}
# {'name': 'kohima', 'registeredUsers': 68041}
# {'name': 'mon', 'registeredUsers': 30439}
# {'name': 'mokokchung', 'registeredUsers': 28574}
# {'name': 'wokha', 'registeredUsers': 17479}
# {'name': 'tuensang', 'registeredUsers': 16666}
# {'name': 'phek', 'registeredUsers': 14221}
# {'name': 'zunheboto', 'registeredUsers': 11283}
# {'name': 'peren', 'registeredUsers': 8085}
# {'name': 'kiphire', 'registeredUsers': 7458}
# {'name': 'dimapur', 'registeredUsers': 8249}
# {'name': 'kohima', 'registeredUsers': 3036}
# {'name': 'mokokchung', 'registeredUsers': 1043}
# {'name': 'mon', 'registeredUsers': 525}
# {'name': 'phek', 'registeredUsers': 487}
# {'name': 'wokha', 'registeredUsers': 465}
# {'name': 'zunheboto', 'registeredUsers': 385}
# {'name': 'tuensang', 'registeredUsers': 377}
# {'name': 'peren', 'registeredUsers': 218}
# {'name': 'kiphire', 'registeredUsers': 168}
# {'name': 'dimapur', 'registeredUsers': 12093}
# {'name': 'kohima', 'registeredUsers': 4395}
# {'name': 'mokokchung', 'registeredUsers': 1616}
# {'name': 'mon', 'registeredUsers': 892}
# {'name': 'phek', 'registeredUsers': 736}
# {'name': 'wokha', 'registeredUsers': 703}
# {'name': 'tuensang', 'registeredUsers': 594}
# {'name': 'zunheboto', 'registeredUsers': 593}
# {'name': 'peren', 'registeredUsers': 358}
# {'name': 'kiphire', 'registeredUsers': 258}
# {'name': 'dimapur', 'registeredUsers': 17039}
# {'name': 'kohima', 'registeredUsers': 6298}
# {'name': 'mokokchung', 'registeredUsers': 2313}
# {'name': 'mon', 'registeredUsers': 1287}
# {'name': 'phek', 'registeredUsers': 1083}
# {'name': 'wokha', 'registeredUsers': 1017}
# {'name': 'tuensang', 'registeredUsers': 934}
# {'name': 'zunheboto', 'registeredUsers': 821}
# {'name': 'peren', 'registeredUsers': 526}
# {'name': 'kiphire', 'registeredUsers': 465}
# {'name': 'dimapur', 'registeredUsers': 22603}
# {'name': 'kohima', 'registeredUsers': 8583}
# {'name': 'mokokchung', 'registeredUsers': 2986}
# {'name': 'mon', 'registeredUsers': 1884}
# {'name': 'phek', 'registeredUsers': 1419}
# {'name': 'wokha', 'registeredUsers': 1391}
# {'name': 'tuensang', 'registeredUsers': 1261}
# {'name': 'zunheboto', 'registeredUsers': 1099}
# {'name': 'peren', 'registeredUsers': 710}
# {'name': 'kiphire', 'registeredUsers': 661}
# {'name': 'dimapur', 'registeredUsers': 124644}
# {'name': 'kohima', 'registeredUsers': 49523}
# {'name': 'mon', 'registeredUsers': 21773}
# {'name': 'mokokchung', 'registeredUsers': 21029}
# {'name': 'wokha', 'registeredUsers': 12743}
# {'name': 'tuensang', 'registeredUsers': 12057}
# {'name': 'phek', 'registeredUsers': 10413}
# {'name': 'zunheboto', 'registeredUsers': 8280}
# {'name': 'peren', 'registeredUsers': 5881}
# {'name': 'kiphire', 'registeredUsers': 5368}
# {'name': 'dimapur', 'registeredUsers': 131738}
# {'name': 'kohima', 'registeredUsers': 52343}
# {'name': 'mon', 'registeredUsers': 23037}
# {'name': 'mokokchung', 'registeredUsers': 22136}
# {'name': 'wokha', 'registeredUsers': 13417}
# {'name': 'tuensang', 'registeredUsers': 12747}
# {'name': 'phek', 'registeredUsers': 11005}
# {'name': 'zunheboto', 'registeredUsers': 8753}
# {'name': 'peren', 'registeredUsers': 6212}
# {'name': 'kiphire', 'registeredUsers': 5687}
# {'name': 'dimapur', 'registeredUsers': 139011}
# {'name': 'kohima', 'registeredUsers': 55046}
# {'name': 'mon', 'registeredUsers': 24237}
# {'name': 'mokokchung', 'registeredUsers': 23192}
# {'name': 'wokha', 'registeredUsers': 14092}
# {'name': 'tuensang', 'registeredUsers': 13393}
# {'name': 'phek', 'registeredUsers': 11494}
# {'name': 'zunheboto', 'registeredUsers': 9128}
# {'name': 'peren', 'registeredUsers': 6534}
# {'name': 'kiphire', 'registeredUsers': 5963}
# {'name': 'dimapur', 'registeredUsers': 145923}
# {'name': 'kohima', 'registeredUsers': 57592}
# {'name': 'mon', 'registeredUsers': 25340}
# {'name': 'mokokchung', 'registeredUsers': 24045}
# {'name': 'wokha', 'registeredUsers': 14702}
# {'name': 'tuensang', 'registeredUsers': 13900}
# {'name': 'phek', 'registeredUsers': 11847}
# {'name': 'zunheboto', 'registeredUsers': 9422}
# {'name': 'peren', 'registeredUsers': 6750}
# {'name': 'kiphire', 'registeredUsers': 6211}
# {'name': 'dimapur', 'registeredUsers': 94968}
# {'name': 'kohima', 'registeredUsers': 37488}
# {'name': 'mon', 'registeredUsers': 16154}
# {'name': 'mokokchung', 'registeredUsers': 15634}
# {'name': 'wokha', 'registeredUsers': 9531}
# {'name': 'tuensang', 'registeredUsers': 8866}
# {'name': 'phek', 'registeredUsers': 7536}
# {'name': 'zunheboto', 'registeredUsers': 6013}
# {'name': 'peren', 'registeredUsers': 4286}
# {'name': 'kiphire', 'registeredUsers': 3904}
# {'name': 'dimapur', 'registeredUsers': 101835}
# {'name': 'kohima', 'registeredUsers': 40277}
# {'name': 'mon', 'registeredUsers': 17389}
# {'name': 'mokokchung', 'registeredUsers': 16857}
# {'name': 'wokha', 'registeredUsers': 10232}
# {'name': 'tuensang', 'registeredUsers': 9565}
# {'name': 'phek', 'registeredUsers': 8134}
# {'name': 'zunheboto', 'registeredUsers': 6487}
# {'name': 'peren', 'registeredUsers': 4641}
# {'name': 'kiphire', 'registeredUsers': 4224}
# {'name': 'dimapur', 'registeredUsers': 109644}
# {'name': 'kohima', 'registeredUsers': 43467}
# {'name': 'mon', 'registeredUsers': 18911}
# {'name': 'mokokchung', 'registeredUsers': 18340}
# {'name': 'wokha', 'registeredUsers': 11126}
# {'name': 'tuensang', 'registeredUsers': 10433}
# {'name': 'phek', 'registeredUsers': 8933}
# {'name': 'zunheboto', 'registeredUsers': 7147}
# {'name': 'peren', 'registeredUsers': 5089}
# {'name': 'kiphire', 'registeredUsers': 4626}
# {'name': 'dimapur', 'registeredUsers': 117388}
# {'name': 'kohima', 'registeredUsers': 46621}
# {'name': 'mon', 'registeredUsers': 20409}
# {'name': 'mokokchung', 'registeredUsers': 19747}
# {'name': 'wokha', 'registeredUsers': 11994}
# {'name': 'tuensang', 'registeredUsers': 11300}
# {'name': 'phek', 'registeredUsers': 9753}
# {'name': 'zunheboto', 'registeredUsers': 7765}
# {'name': 'peren', 'registeredUsers': 5509}
# {'name': 'kiphire', 'registeredUsers': 5047}
# {'name': 'dimapur', 'registeredUsers': 53696}
# {'name': 'kohima', 'registeredUsers': 20644}
# {'name': 'mokokchung', 'registeredUsers': 7626}
# {'name': 'mon', 'registeredUsers': 5747}
# {'name': 'wokha', 'registeredUsers': 4118}
# {'name': 'phek', 'registeredUsers': 3637}
# {'name': 'tuensang', 'registeredUsers': 3634}
# {'name': 'zunheboto', 'registeredUsers': 2898}
# {'name': 'peren', 'registeredUsers': 1899}
# {'name': 'kiphire', 'registeredUsers': 1814}
# {'name': 'dimapur', 'registeredUsers': 63398}
# {'name': 'kohima', 'registeredUsers': 24236}
# {'name': 'mokokchung', 'registeredUsers': 9559}
# {'name': 'mon', 'registeredUsers': 7917}
# {'name': 'wokha', 'registeredUsers': 5296}
# {'name': 'tuensang', 'registeredUsers': 4779}
# {'name': 'phek', 'registeredUsers': 4535}
# {'name': 'zunheboto', 'registeredUsers': 3647}
# {'name': 'peren', 'registeredUsers': 2534}
# {'name': 'kiphire', 'registeredUsers': 2423}
# {'name': 'dimapur', 'registeredUsers': 79061}
# {'name': 'kohima', 'registeredUsers': 31483}
# {'name': 'mon', 'registeredUsers': 13591}
# {'name': 'mokokchung', 'registeredUsers': 13155}
# {'name': 'wokha', 'registeredUsers': 7980}
# {'name': 'tuensang', 'registeredUsers': 7220}
# {'name': 'phek', 'registeredUsers': 6151}
# {'name': 'zunheboto', 'registeredUsers': 4942}
# {'name': 'peren', 'registeredUsers': 3486}
# {'name': 'kiphire', 'registeredUsers': 3306}
# {'name': 'dimapur', 'registeredUsers': 87807}
# {'name': 'kohima', 'registeredUsers': 34872}
# {'name': 'mon', 'registeredUsers': 14932}
# {'name': 'mokokchung', 'registeredUsers': 14511}
# {'name': 'wokha', 'registeredUsers': 8821}
# {'name': 'tuensang', 'registeredUsers': 8177}
# {'name': 'phek', 'registeredUsers': 6888}
# {'name': 'zunheboto', 'registeredUsers': 5541}
# {'name': 'peren', 'registeredUsers': 3919}
# {'name': 'kiphire', 'registeredUsers': 3629}
# {'name': 'dimapur', 'registeredUsers': 28091}
# {'name': 'kohima', 'registeredUsers': 10747}
# {'name': 'mokokchung', 'registeredUsers': 3721}
# {'name': 'mon', 'registeredUsers': 2458}
# {'name': 'wokha', 'registeredUsers': 1830}
# {'name': 'phek', 'registeredUsers': 1727}
# {'name': 'tuensang', 'registeredUsers': 1678}
# {'name': 'zunheboto', 'registeredUsers': 1374}
# {'name': 'peren', 'registeredUsers': 884}
# {'name': 'kiphire', 'registeredUsers': 862}
# {'name': 'dimapur', 'registeredUsers': 34567}
# {'name': 'kohima', 'registeredUsers': 13108}
# {'name': 'mokokchung', 'registeredUsers': 4655}
# {'name': 'mon', 'registeredUsers': 3210}
# {'name': 'wokha', 'registeredUsers': 2411}
# {'name': 'tuensang', 'registeredUsers': 2152}
# {'name': 'phek', 'registeredUsers': 2143}
# {'name': 'zunheboto', 'registeredUsers': 1680}
# {'name': 'peren', 'registeredUsers': 1148}
# {'name': 'kiphire', 'registeredUsers': 1084}
# {'name': 'dimapur', 'registeredUsers': 41036}
# {'name': 'kohima', 'registeredUsers': 15677}
# {'name': 'mokokchung', 'registeredUsers': 5593}
# {'name': 'mon', 'registeredUsers': 3976}
# {'name': 'wokha', 'registeredUsers': 2961}
# {'name': 'phek', 'registeredUsers': 2642}
# {'name': 'tuensang', 'registeredUsers': 2599}
# {'name': 'zunheboto', 'registeredUsers': 2058}
# {'name': 'peren', 'registeredUsers': 1377}
# {'name': 'kiphire', 'registeredUsers': 1251}
# {'name': 'dimapur', 'registeredUsers': 47000}
# {'name': 'kohima', 'registeredUsers': 18232}
# {'name': 'mokokchung', 'registeredUsers': 6606}
# {'name': 'mon', 'registeredUsers': 4863}
# {'name': 'wokha', 'registeredUsers': 3540}
# {'name': 'phek', 'registeredUsers': 3109}
# {'name': 'tuensang', 'registeredUsers': 3081}
# {'name': 'zunheboto', 'registeredUsers': 2475}
# {'name': 'peren', 'registeredUsers': 1623}
# {'name': 'kiphire', 'registeredUsers': 1460}
# {'name': 'dimapur', 'registeredUsers': 179628}
# {'name': 'kohima', 'registeredUsers': 70998}
# {'name': 'mon', 'registeredUsers': 31941}
# {'name': 'mokokchung', 'registeredUsers': 29997}
# {'name': 'wokha', 'registeredUsers': 18309}
# {'name': 'tuensang', 'registeredUsers': 17533}
# {'name': 'phek', 'registeredUsers': 15014}
# {'name': 'zunheboto', 'registeredUsers': 11884}
# {'name': 'peren', 'registeredUsers': 8518}
# {'name': 'kiphire', 'registeredUsers': 7857}
# {'name': 'dimapur', 'registeredUsers': 186894}
# {'name': 'kohima', 'registeredUsers': 73786}
# {'name': 'mon', 'registeredUsers': 33389}
# {'name': 'mokokchung', 'registeredUsers': 31277}
# {'name': 'wokha', 'registeredUsers': 19109}
# {'name': 'tuensang', 'registeredUsers': 18244}
# {'name': 'phek', 'registeredUsers': 15586}
# {'name': 'zunheboto', 'registeredUsers': 12347}
# {'name': 'peren', 'registeredUsers': 8850}
# {'name': 'kiphire', 'registeredUsers': 8155}
# {'name': 'dimapur', 'registeredUsers': 151915}
# {'name': 'kohima', 'registeredUsers': 75287}
# {'name': 'chumoukedima', 'registeredUsers': 69452}
# {'name': 'mon', 'registeredUsers': 30747}
# {'name': 'mokokchung', 'registeredUsers': 30298}
# {'name': 'wokha', 'registeredUsers': 17356}
# {'name': 'tuensang', 'registeredUsers': 15288}
# {'name': 'phek', 'registeredUsers': 14031}
# {'name': 'zunheboto', 'registeredUsers': 11546}
# {'name': 'peren', 'registeredUsers': 10338}
# {'name': 'dimapur', 'registeredUsers': 156794}
# {'name': 'kohima', 'registeredUsers': 77834}
# {'name': 'chumoukedima', 'registeredUsers': 72338}
# {'name': 'mon', 'registeredUsers': 32068}
# {'name': 'mokokchung', 'registeredUsers': 31411}
# {'name': 'wokha', 'registeredUsers': 18036}
# {'name': 'tuensang', 'registeredUsers': 15950}
# {'name': 'phek', 'registeredUsers': 14609}
# {'name': 'zunheboto', 'registeredUsers': 12099}
# {'name': 'peren', 'registeredUsers': 10820}
# {'name': 'dehradun', 'registeredUsers': 1318049}
# {'name': 'haridwar', 'registeredUsers': 928785}
# {'name': 'udham singh nagar', 'registeredUsers': 792853}
# {'name': 'nainital', 'registeredUsers': 425816}
# {'name': 'pauri garhwal', 'registeredUsers': 213655}
# {'name': 'tehri garhwal', 'registeredUsers': 164792}
# {'name': 'almora', 'registeredUsers': 140885}
# {'name': 'pithoragarh', 'registeredUsers': 117070}
# {'name': 'chamoli', 'registeredUsers': 101718}
# {'name': 'uttarkashi', 'registeredUsers': 82107}
# {'name': 'dehradun', 'registeredUsers': 1367275}
# {'name': 'haridwar', 'registeredUsers': 965635}
# {'name': 'udham singh nagar', 'registeredUsers': 825744}
# {'name': 'nainital', 'registeredUsers': 442626}
# {'name': 'pauri garhwal', 'registeredUsers': 222967}
# {'name': 'tehri garhwal', 'registeredUsers': 172215}
# {'name': 'almora', 'registeredUsers': 147376}
# {'name': 'pithoragarh', 'registeredUsers': 122297}
# {'name': 'chamoli', 'registeredUsers': 106415}
# {'name': 'uttarkashi', 'registeredUsers': 85915}
# {'name': 'dehradun', 'registeredUsers': 1419173}
# {'name': 'haridwar', 'registeredUsers': 1003648}
# {'name': 'udham singh nagar', 'registeredUsers': 858970}
# {'name': 'nainital', 'registeredUsers': 460046}
# {'name': 'pauri garhwal', 'registeredUsers': 232186}
# {'name': 'tehri garhwal', 'registeredUsers': 179437}
# {'name': 'almora', 'registeredUsers': 153779}
# {'name': 'pithoragarh', 'registeredUsers': 127530}
# {'name': 'chamoli', 'registeredUsers': 110883}
# {'name': 'uttarkashi', 'registeredUsers': 89519}
# {'name': 'dehradun', 'registeredUsers': 1466612}
# {'name': 'haridwar', 'registeredUsers': 1039146}
# {'name': 'udham singh nagar', 'registeredUsers': 890334}
# {'name': 'nainital', 'registeredUsers': 476343}
# {'name': 'pauri garhwal', 'registeredUsers': 240922}
# {'name': 'tehri garhwal', 'registeredUsers': 186005}
# {'name': 'almora', 'registeredUsers': 159623}
# {'name': 'pithoragarh', 'registeredUsers': 132323}
# {'name': 'chamoli', 'registeredUsers': 115112}
# {'name': 'uttarkashi', 'registeredUsers': 92982}
# {'name': 'dehradun', 'registeredUsers': 147998}
# {'name': 'haridwar', 'registeredUsers': 104823}
# {'name': 'udham singh nagar', 'registeredUsers': 100236}
# {'name': 'nainital', 'registeredUsers': 49083}
# {'name': 'pauri garhwal', 'registeredUsers': 20425}
# {'name': 'tehri garhwal', 'registeredUsers': 13030}
# {'name': 'almora', 'registeredUsers': 11367}
# {'name': 'pithoragarh', 'registeredUsers': 8836}
# {'name': 'chamoli', 'registeredUsers': 7493}
# {'name': 'uttarkashi', 'registeredUsers': 5816}
# {'name': 'dehradun', 'registeredUsers': 198296}
# {'name': 'haridwar', 'registeredUsers': 140718}
# {'name': 'udham singh nagar', 'registeredUsers': 132549}
# {'name': 'nainital', 'registeredUsers': 65142}
# {'name': 'pauri garhwal', 'registeredUsers': 28153}
# {'name': 'tehri garhwal', 'registeredUsers': 18021}
# {'name': 'almora', 'registeredUsers': 15473}
# {'name': 'pithoragarh', 'registeredUsers': 12486}
# {'name': 'chamoli', 'registeredUsers': 10502}
# {'name': 'uttarkashi', 'registeredUsers': 8227}
# {'name': 'dehradun', 'registeredUsers': 246477}
# {'name': 'haridwar', 'registeredUsers': 174526}
# {'name': 'udham singh nagar', 'registeredUsers': 162754}
# {'name': 'nainital', 'registeredUsers': 79936}
# {'name': 'pauri garhwal', 'registeredUsers': 36059}
# {'name': 'tehri garhwal', 'registeredUsers': 23575}
# {'name': 'almora', 'registeredUsers': 20152}
# {'name': 'pithoragarh', 'registeredUsers': 16483}
# {'name': 'chamoli', 'registeredUsers': 14112}
# {'name': 'uttarkashi', 'registeredUsers': 10793}
# {'name': 'dehradun', 'registeredUsers': 306969}
# {'name': 'haridwar', 'registeredUsers': 217634}
# {'name': 'udham singh nagar', 'registeredUsers': 200079}
# {'name': 'nainital', 'registeredUsers': 98591}
# {'name': 'pauri garhwal', 'registeredUsers': 45898}
# {'name': 'tehri garhwal', 'registeredUsers': 30089}
# {'name': 'almora', 'registeredUsers': 26282}
# {'name': 'pithoragarh', 'registeredUsers': 21378}
# {'name': 'chamoli', 'registeredUsers': 18391}
# {'name': 'uttarkashi', 'registeredUsers': 14114}
# {'name': 'dehradun', 'registeredUsers': 1088710}
# {'name': 'haridwar', 'registeredUsers': 760173}
# {'name': 'udham singh nagar', 'registeredUsers': 647495}
# {'name': 'nainital', 'registeredUsers': 351226}
# {'name': 'pauri garhwal', 'registeredUsers': 177248}
# {'name': 'tehri garhwal', 'registeredUsers': 136364}
# {'name': 'almora', 'registeredUsers': 117262}
# {'name': 'pithoragarh', 'registeredUsers': 96837}
# {'name': 'chamoli', 'registeredUsers': 84165}
# {'name': 'uttarkashi', 'registeredUsers': 67713}
# {'name': 'dehradun', 'registeredUsers': 1146386}
# {'name': 'haridwar', 'registeredUsers': 802321}
# {'name': 'udham singh nagar', 'registeredUsers': 683908}
# {'name': 'nainital', 'registeredUsers': 370360}
# {'name': 'pauri garhwal', 'registeredUsers': 187078}
# {'name': 'tehri garhwal', 'registeredUsers': 144049}
# {'name': 'almora', 'registeredUsers': 123856}
# {'name': 'pithoragarh', 'registeredUsers': 102347}
# {'name': 'chamoli', 'registeredUsers': 88939}
# {'name': 'uttarkashi', 'registeredUsers': 71641}
# {'name': 'dehradun', 'registeredUsers': 1205785}
# {'name': 'haridwar', 'registeredUsers': 846066}
# {'name': 'udham singh nagar', 'registeredUsers': 722008}
# {'name': 'nainital', 'registeredUsers': 389791}
# {'name': 'pauri garhwal', 'registeredUsers': 196481}
# {'name': 'tehri garhwal', 'registeredUsers': 151445}
# {'name': 'almora', 'registeredUsers': 129898}
# {'name': 'pithoragarh', 'registeredUsers': 107498}
# {'name': 'chamoli', 'registeredUsers': 93488}
# {'name': 'uttarkashi', 'registeredUsers': 75369}
# {'name': 'dehradun', 'registeredUsers': 1262999}
# {'name': 'haridwar', 'registeredUsers': 887967}
# {'name': 'udham singh nagar', 'registeredUsers': 757652}
# {'name': 'nainital', 'registeredUsers': 407806}
# {'name': 'pauri garhwal', 'registeredUsers': 204585}
# {'name': 'tehri garhwal', 'registeredUsers': 157634}
# {'name': 'almora', 'registeredUsers': 134730}
# {'name': 'pithoragarh', 'registeredUsers': 111983}
# {'name': 'chamoli', 'registeredUsers': 97308}
# {'name': 'uttarkashi', 'registeredUsers': 78484}
# {'name': 'dehradun', 'registeredUsers': 840361}
# {'name': 'haridwar', 'registeredUsers': 580532}
# {'name': 'udham singh nagar', 'registeredUsers': 492646}
# {'name': 'nainital', 'registeredUsers': 269308}
# {'name': 'pauri garhwal', 'registeredUsers': 133484}
# {'name': 'tehri garhwal', 'registeredUsers': 102085}
# {'name': 'almora', 'registeredUsers': 87354}
# {'name': 'pithoragarh', 'registeredUsers': 72579}
# {'name': 'chamoli', 'registeredUsers': 62779}
# {'name': 'uttarkashi', 'registeredUsers': 50696}
# {'name': 'dehradun', 'registeredUsers': 898504}
# {'name': 'haridwar', 'registeredUsers': 622292}
# {'name': 'udham singh nagar', 'registeredUsers': 528392}
# {'name': 'nainital', 'registeredUsers': 288162}
# {'name': 'pauri garhwal', 'registeredUsers': 143460}
# {'name': 'tehri garhwal', 'registeredUsers': 109890}
# {'name': 'almora', 'registeredUsers': 94196}
# {'name': 'pithoragarh', 'registeredUsers': 78079}
# {'name': 'chamoli', 'registeredUsers': 67712}
# {'name': 'uttarkashi', 'registeredUsers': 54582}
# {'name': 'dehradun', 'registeredUsers': 963594}
# {'name': 'haridwar', 'registeredUsers': 669249}
# {'name': 'udham singh nagar', 'registeredUsers': 568881}
# {'name': 'nainital', 'registeredUsers': 309820}
# {'name': 'pauri garhwal', 'registeredUsers': 155054}
# {'name': 'tehri garhwal', 'registeredUsers': 119032}
# {'name': 'almora', 'registeredUsers': 102118}
# {'name': 'pithoragarh', 'registeredUsers': 84476}
# {'name': 'chamoli', 'registeredUsers': 73432}
# {'name': 'uttarkashi', 'registeredUsers': 59174}
# {'name': 'dehradun', 'registeredUsers': 1028085}
# {'name': 'haridwar', 'registeredUsers': 716044}
# {'name': 'udham singh nagar', 'registeredUsers': 609138}
# {'name': 'nainital', 'registeredUsers': 330999}
# {'name': 'pauri garhwal', 'registeredUsers': 166482}
# {'name': 'tehri garhwal', 'registeredUsers': 127893}
# {'name': 'almora', 'registeredUsers': 109803}
# {'name': 'pithoragarh', 'registeredUsers': 90791}
# {'name': 'chamoli', 'registeredUsers': 78848}
# {'name': 'uttarkashi', 'registeredUsers': 63536}
# {'name': 'dehradun', 'registeredUsers': 593420}
# {'name': 'haridwar', 'registeredUsers': 408768}
# {'name': 'udham singh nagar', 'registeredUsers': 351112}
# {'name': 'nainital', 'registeredUsers': 186948}
# {'name': 'pauri garhwal', 'registeredUsers': 90270}
# {'name': 'tehri garhwal', 'registeredUsers': 66293}
# {'name': 'almora', 'registeredUsers': 55964}
# {'name': 'pithoragarh', 'registeredUsers': 46554}
# {'name': 'chamoli', 'registeredUsers': 40668}
# {'name': 'uttarkashi', 'registeredUsers': 32713}
# {'name': 'dehradun', 'registeredUsers': 649026}
# {'name': 'haridwar', 'registeredUsers': 448939}
# {'name': 'udham singh nagar', 'registeredUsers': 383547}
# {'name': 'nainital', 'registeredUsers': 206076}
# {'name': 'pauri garhwal', 'registeredUsers': 101276}
# {'name': 'tehri garhwal', 'registeredUsers': 75996}
# {'name': 'almora', 'registeredUsers': 64523}
# {'name': 'pithoragarh', 'registeredUsers': 53375}
# {'name': 'chamoli', 'registeredUsers': 46467}
# {'name': 'uttarkashi', 'registeredUsers': 37671}
# {'name': 'dehradun', 'registeredUsers': 711303}
# {'name': 'haridwar', 'registeredUsers': 491252}
# {'name': 'udham singh nagar', 'registeredUsers': 418390}
# {'name': 'nainital', 'registeredUsers': 227497}
# {'name': 'pauri garhwal', 'registeredUsers': 112287}
# {'name': 'tehri garhwal', 'registeredUsers': 85276}
# {'name': 'almora', 'registeredUsers': 72829}
# {'name': 'pithoragarh', 'registeredUsers': 60279}
# {'name': 'chamoli', 'registeredUsers': 52184}
# {'name': 'uttarkashi', 'registeredUsers': 42144}
# {'name': 'dehradun', 'registeredUsers': 779564}
# {'name': 'haridwar', 'registeredUsers': 537058}
# {'name': 'udham singh nagar', 'registeredUsers': 456356}
# {'name': 'nainital', 'registeredUsers': 249856}
# {'name': 'pauri garhwal', 'registeredUsers': 123892}
# {'name': 'tehri garhwal', 'registeredUsers': 94520}
# {'name': 'almora', 'registeredUsers': 81020}
# {'name': 'pithoragarh', 'registeredUsers': 67024}
# {'name': 'chamoli', 'registeredUsers': 58039}
# {'name': 'uttarkashi', 'registeredUsers': 46810}
# {'name': 'dehradun', 'registeredUsers': 369578}
# {'name': 'haridwar', 'registeredUsers': 262411}
# {'name': 'udham singh nagar', 'registeredUsers': 238514}
# {'name': 'nainital', 'registeredUsers': 118824}
# {'name': 'pauri garhwal', 'registeredUsers': 56173}
# {'name': 'tehri garhwal', 'registeredUsers': 37689}
# {'name': 'almora', 'registeredUsers': 33092}
# {'name': 'pithoragarh', 'registeredUsers': 26621}
# {'name': 'chamoli', 'registeredUsers': 23274}
# {'name': 'uttarkashi', 'registeredUsers': 17873}
# {'name': 'dehradun', 'registeredUsers': 428353}
# {'name': 'haridwar', 'registeredUsers': 299436}
# {'name': 'udham singh nagar', 'registeredUsers': 266958}
# {'name': 'nainital', 'registeredUsers': 137114}
# {'name': 'pauri garhwal', 'registeredUsers': 65607}
# {'name': 'tehri garhwal', 'registeredUsers': 45652}
# {'name': 'almora', 'registeredUsers': 39593}
# {'name': 'pithoragarh', 'registeredUsers': 32308}
# {'name': 'chamoli', 'registeredUsers': 28063}
# {'name': 'uttarkashi', 'registeredUsers': 21969}
# {'name': 'dehradun', 'registeredUsers': 486157}
# {'name': 'haridwar', 'registeredUsers': 334619}
# {'name': 'udham singh nagar', 'registeredUsers': 292858}
# {'name': 'nainital', 'registeredUsers': 153561}
# {'name': 'pauri garhwal', 'registeredUsers': 73363}
# {'name': 'tehri garhwal', 'registeredUsers': 52090}
# {'name': 'almora', 'registeredUsers': 44182}
# {'name': 'pithoragarh', 'registeredUsers': 36353}
# {'name': 'chamoli', 'registeredUsers': 32036}
# {'name': 'uttarkashi', 'registeredUsers': 25151}
# {'name': 'dehradun', 'registeredUsers': 537026}
# {'name': 'haridwar', 'registeredUsers': 368737}
# {'name': 'udham singh nagar', 'registeredUsers': 319839}
# {'name': 'nainital', 'registeredUsers': 169212}
# {'name': 'pauri garhwal', 'registeredUsers': 81489}
# {'name': 'tehri garhwal', 'registeredUsers': 58542}
# ...
# {'name': 'saiha', 'registeredUsers': 901}
# {'name': 'aizawl', 'registeredUsers': 21865}
# {'name': 'lunglei', 'registeredUsers': 4926}
# {'name': 'lawngtlai', 'registeredUsers': 3255}
# {'name': 'kolasib', 'registeredUsers': 2929}
# {'name': 'champhai', 'registeredUsers': 2067}
# {'name': 'mamit', 'registeredUsers': 1996}
# {'name': 'serchhip', 'registeredUsers': 1735}
# {'name': 'saiha', 'registeredUsers': 1036}
# {'name': 'aizawl', 'registeredUsers': 84499}
# {'name': 'lunglei', 'registeredUsers': 20891}
# {'name': 'lawngtlai', 'registeredUsers': 16779}
# {'name': 'kolasib', 'registeredUsers': 12085}
# {'name': 'champhai', 'registeredUsers': 9876}
# {'name': 'mamit', 'registeredUsers': 9085}
# {'name': 'serchhip', 'registeredUsers': 6995}
# {'name': 'saiha', 'registeredUsers': 4916}
# {'name': 'aizawl', 'registeredUsers': 87821}
# {'name': 'lunglei', 'registeredUsers': 21695}
# {'name': 'lawngtlai', 'registeredUsers': 17421}
# {'name': 'kolasib', 'registeredUsers': 12540}
# {'name': 'champhai', 'registeredUsers': 10246}
# {'name': 'mamit', 'registeredUsers': 9452}
# {'name': 'serchhip', 'registeredUsers': 7272}
# {'name': 'saiha', 'registeredUsers': 5093}
# {'name': 'aizawl', 'registeredUsers': 109335}
# {'name': 'lunglei', 'registeredUsers': 25124}
# {'name': 'lawngtlai', 'registeredUsers': 24345}
# {'name': 'kolasib', 'registeredUsers': 17391}
# {'name': 'mamit', 'registeredUsers': 14535}
# {'name': 'serchhip', 'registeredUsers': 8785}
# {'name': 'champhai', 'registeredUsers': 8177}
# {'name': 'siaha', 'registeredUsers': 7056}
# {'name': 'saitual', 'registeredUsers': 4674}
# {'name': 'hnahthial', 'registeredUsers': 2797}
# {'name': 'aizawl', 'registeredUsers': 113860}
# {'name': 'lunglei', 'registeredUsers': 26236}
# {'name': 'lawngtlai', 'registeredUsers': 25334}
# {'name': 'kolasib', 'registeredUsers': 18177}
# {'name': 'mamit', 'registeredUsers': 15222}
# {'name': 'serchhip', 'registeredUsers': 9183}
# {'name': 'champhai', 'registeredUsers': 8509}
# {'name': 'siaha', 'registeredUsers': 7374}
# {'name': 'saitual', 'registeredUsers': 4829}
# {'name': 'hnahthial', 'registeredUsers': 2932}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3434422}
# {'name': 'lucknow', 'registeredUsers': 2858255}
# {'name': 'ghaziabad', 'registeredUsers': 2798185}
# {'name': 'prayagraj', 'registeredUsers': 1847496}
# {'name': 'kanpur nagar', 'registeredUsers': 1751281}
# {'name': 'varanasi', 'registeredUsers': 1718122}
# {'name': 'agra', 'registeredUsers': 1567104}
# {'name': 'gorakhpur', 'registeredUsers': 1263672}
# {'name': 'meerut', 'registeredUsers': 1178230}
# {'name': 'bareilly', 'registeredUsers': 1073906}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3562632}
# {'name': 'lucknow', 'registeredUsers': 2965623}
# {'name': 'ghaziabad', 'registeredUsers': 2904454}
# {'name': 'prayagraj', 'registeredUsers': 1923415}
# {'name': 'kanpur nagar', 'registeredUsers': 1819802}
# {'name': 'varanasi', 'registeredUsers': 1786176}
# {'name': 'agra', 'registeredUsers': 1630258}
# {'name': 'gorakhpur', 'registeredUsers': 1315842}
# {'name': 'meerut', 'registeredUsers': 1224499}
# {'name': 'bareilly', 'registeredUsers': 1119305}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3694806}
# {'name': 'lucknow', 'registeredUsers': 3079592}
# {'name': 'ghaziabad', 'registeredUsers': 3015494}
# {'name': 'prayagraj', 'registeredUsers': 2002831}
# {'name': 'kanpur nagar', 'registeredUsers': 1892032}
# {'name': 'varanasi', 'registeredUsers': 1857307}
# {'name': 'agra', 'registeredUsers': 1696452}
# {'name': 'gorakhpur', 'registeredUsers': 1370080}
# {'name': 'meerut', 'registeredUsers': 1272850}
# {'name': 'bareilly', 'registeredUsers': 1164885}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3820774}
# {'name': 'lucknow', 'registeredUsers': 3186571}
# {'name': 'ghaziabad', 'registeredUsers': 3120359}
# {'name': 'prayagraj', 'registeredUsers': 2077118}
# {'name': 'kanpur nagar', 'registeredUsers': 1960237}
# {'name': 'varanasi', 'registeredUsers': 1924417}
# {'name': 'agra', 'registeredUsers': 1757237}
# {'name': 'gorakhpur', 'registeredUsers': 1422116}
# {'name': 'meerut', 'registeredUsers': 1317753}
# {'name': 'bareilly', 'registeredUsers': 1207371}
# {'name': 'gautam buddha nagar', 'registeredUsers': 448768}
# {'name': 'lucknow', 'registeredUsers': 380070}
# {'name': 'ghaziabad', 'registeredUsers': 329683}
# {'name': 'prayagraj', 'registeredUsers': 220198}
# {'name': 'kanpur nagar', 'registeredUsers': 208389}
# {'name': 'varanasi', 'registeredUsers': 206788}
# {'name': 'agra', 'registeredUsers': 148387}
# {'name': 'gorakhpur', 'registeredUsers': 132769}
# {'name': 'meerut', 'registeredUsers': 123619}
# {'name': 'bareilly', 'registeredUsers': 112369}
# {'name': 'gautam buddha nagar', 'registeredUsers': 586350}
# {'name': 'lucknow', 'registeredUsers': 506261}
# {'name': 'ghaziabad', 'registeredUsers': 434115}
# {'name': 'prayagraj', 'registeredUsers': 297113}
# {'name': 'varanasi', 'registeredUsers': 288325}
# {'name': 'kanpur nagar', 'registeredUsers': 285101}
# {'name': 'agra', 'registeredUsers': 205298}
# {'name': 'gorakhpur', 'registeredUsers': 181126}
# {'name': 'meerut', 'registeredUsers': 167212}
# {'name': 'bareilly', 'registeredUsers': 152939}
# {'name': 'gautam buddha nagar', 'registeredUsers': 727480}
# {'name': 'lucknow', 'registeredUsers': 620328}
# {'name': 'ghaziabad', 'registeredUsers': 538532}
# {'name': 'prayagraj', 'registeredUsers': 363743}
# {'name': 'varanasi', 'registeredUsers': 352604}
# {'name': 'kanpur nagar', 'registeredUsers': 349250}
# {'name': 'agra', 'registeredUsers': 257453}
# {'name': 'gorakhpur', 'registeredUsers': 224409}
# {'name': 'meerut', 'registeredUsers': 205977}
# {'name': 'bareilly', 'registeredUsers': 187467}
# {'name': 'gautam buddha nagar', 'registeredUsers': 951342}
# {'name': 'lucknow', 'registeredUsers': 765152}
# {'name': 'ghaziabad', 'registeredUsers': 713372}
# {'name': 'prayagraj', 'registeredUsers': 451019}
# {'name': 'varanasi', 'registeredUsers': 447144}
# {'name': 'kanpur nagar', 'registeredUsers': 434315}
# {'name': 'agra', 'registeredUsers': 322749}
# {'name': 'gorakhpur', 'registeredUsers': 279761}
# {'name': 'meerut', 'registeredUsers': 258843}
# {'name': 'bareilly', 'registeredUsers': 233073}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2822463}
# {'name': 'lucknow', 'registeredUsers': 2348173}
# {'name': 'ghaziabad', 'registeredUsers': 2298103}
# {'name': 'prayagraj', 'registeredUsers': 1504572}
# {'name': 'kanpur nagar', 'registeredUsers': 1431918}
# {'name': 'varanasi', 'registeredUsers': 1406056}
# {'name': 'agra', 'registeredUsers': 1279852}
# {'name': 'gorakhpur', 'registeredUsers': 1027283}
# {'name': 'meerut', 'registeredUsers': 967325}
# {'name': 'bareilly', 'registeredUsers': 875033}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2973360}
# {'name': 'lucknow', 'registeredUsers': 2474317}
# {'name': 'ghaziabad', 'registeredUsers': 2421605}
# {'name': 'prayagraj', 'registeredUsers': 1590032}
# {'name': 'kanpur nagar', 'registeredUsers': 1510491}
# {'name': 'varanasi', 'registeredUsers': 1483315}
# {'name': 'agra', 'registeredUsers': 1351856}
# {'name': 'gorakhpur', 'registeredUsers': 1086399}
# {'name': 'meerut', 'registeredUsers': 1020429}
# {'name': 'bareilly', 'registeredUsers': 925536}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3130224}
# {'name': 'lucknow', 'registeredUsers': 2604663}
# {'name': 'ghaziabad', 'registeredUsers': 2549377}
# {'name': 'prayagraj', 'registeredUsers': 1678668}
# {'name': 'kanpur nagar', 'registeredUsers': 1592126}
# {'name': 'varanasi', 'registeredUsers': 1563730}
# {'name': 'agra', 'registeredUsers': 1426154}
# {'name': 'gorakhpur', 'registeredUsers': 1148103}
# {'name': 'meerut', 'registeredUsers': 1075255}
# {'name': 'bareilly', 'registeredUsers': 977218}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3286371}
# {'name': 'lucknow', 'registeredUsers': 2734333}
# {'name': 'ghaziabad', 'registeredUsers': 2676888}
# {'name': 'prayagraj', 'registeredUsers': 1763014}
# {'name': 'kanpur nagar', 'registeredUsers': 1673173}
# {'name': 'varanasi', 'registeredUsers': 1641943}
# {'name': 'agra', 'registeredUsers': 1497144}
# {'name': 'gorakhpur', 'registeredUsers': 1205580}
# {'name': 'meerut', 'registeredUsers': 1127324}
# {'name': 'bareilly', 'registeredUsers': 1025341}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2181874}
# {'name': 'lucknow', 'registeredUsers': 1813076}
# {'name': 'ghaziabad', 'registeredUsers': 1773332}
# {'name': 'prayagraj', 'registeredUsers': 1143612}
# {'name': 'kanpur nagar', 'registeredUsers': 1100587}
# {'name': 'varanasi', 'registeredUsers': 1079309}
# {'name': 'agra', 'registeredUsers': 974389}
# {'name': 'gorakhpur', 'registeredUsers': 780306}
# {'name': 'meerut', 'registeredUsers': 741901}
# {'name': 'bareilly', 'registeredUsers': 662143}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2329954}
# {'name': 'lucknow', 'registeredUsers': 1937173}
# {'name': 'ghaziabad', 'registeredUsers': 1895314}
# {'name': 'prayagraj', 'registeredUsers': 1225800}
# {'name': 'kanpur nagar', 'registeredUsers': 1176708}
# {'name': 'varanasi', 'registeredUsers': 1154661}
# {'name': 'agra', 'registeredUsers': 1044788}
# {'name': 'gorakhpur', 'registeredUsers': 835887}
# {'name': 'meerut', 'registeredUsers': 794314}
# {'name': 'bareilly', 'registeredUsers': 710778}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2496114}
# {'name': 'lucknow', 'registeredUsers': 2076033}
# {'name': 'ghaziabad', 'registeredUsers': 2031752}
# {'name': 'prayagraj', 'registeredUsers': 1320432}
# {'name': 'kanpur nagar', 'registeredUsers': 1263050}
# {'name': 'varanasi', 'registeredUsers': 1239725}
# {'name': 'agra', 'registeredUsers': 1124720}
# {'name': 'gorakhpur', 'registeredUsers': 900171}
# {'name': 'meerut', 'registeredUsers': 853246}
# {'name': 'bareilly', 'registeredUsers': 766809}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2664034}
# {'name': 'lucknow', 'registeredUsers': 2215886}
# {'name': 'ghaziabad', 'registeredUsers': 2169109}
# {'name': 'prayagraj', 'registeredUsers': 1414447}
# {'name': 'kanpur nagar', 'registeredUsers': 1349794}
# {'name': 'varanasi', 'registeredUsers': 1325315}
# {'name': 'agra', 'registeredUsers': 1204274}
# {'name': 'gorakhpur', 'registeredUsers': 964667}
# {'name': 'meerut', 'registeredUsers': 911852}
# {'name': 'bareilly', 'registeredUsers': 821986}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1656331}
# {'name': 'lucknow', 'registeredUsers': 1329098}
# {'name': 'ghaziabad', 'registeredUsers': 1296464}
# {'name': 'prayagraj', 'registeredUsers': 816436}
# {'name': 'kanpur nagar', 'registeredUsers': 788847}
# {'name': 'varanasi', 'registeredUsers': 777234}
# {'name': 'agra', 'registeredUsers': 668251}
# {'name': 'gorakhpur', 'registeredUsers': 539316}
# {'name': 'meerut', 'registeredUsers': 509693}
# {'name': 'bareilly', 'registeredUsers': 452872}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1756163}
# {'name': 'lucknow', 'registeredUsers': 1434386}
# {'name': 'ghaziabad', 'registeredUsers': 1399514}
# {'name': 'prayagraj', 'registeredUsers': 892787}
# {'name': 'kanpur nagar', 'registeredUsers': 864991}
# {'name': 'varanasi', 'registeredUsers': 851213}
# {'name': 'agra', 'registeredUsers': 746336}
# {'name': 'gorakhpur', 'registeredUsers': 600961}
# {'name': 'meerut', 'registeredUsers': 566838}
# {'name': 'bareilly', 'registeredUsers': 507342}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1885370}
# {'name': 'lucknow', 'registeredUsers': 1551932}
# {'name': 'ghaziabad', 'registeredUsers': 1518450}
# {'name': 'prayagraj', 'registeredUsers': 974228}
# {'name': 'kanpur nagar', 'registeredUsers': 941379}
# {'name': 'varanasi', 'registeredUsers': 927313}
# {'name': 'agra', 'registeredUsers': 822893}
# {'name': 'gorakhpur', 'registeredUsers': 661272}
# {'name': 'meerut', 'registeredUsers': 624570}
# {'name': 'bareilly', 'registeredUsers': 558821}
# {'name': 'gautam buddha nagar', 'registeredUsers': 2030178}
# {'name': 'lucknow', 'registeredUsers': 1684510}
# {'name': 'ghaziabad', 'registeredUsers': 1647330}
# {'name': 'prayagraj', 'registeredUsers': 1059982}
# {'name': 'kanpur nagar', 'registeredUsers': 1022768}
# {'name': 'varanasi', 'registeredUsers': 1003989}
# {'name': 'agra', 'registeredUsers': 900497}
# {'name': 'gorakhpur', 'registeredUsers': 722618}
# {'name': 'meerut', 'registeredUsers': 686266}
# {'name': 'bareilly', 'registeredUsers': 611236}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1143614}
# {'name': 'lucknow', 'registeredUsers': 896208}
# {'name': 'ghaziabad', 'registeredUsers': 859583}
# {'name': 'prayagraj', 'registeredUsers': 532230}
# {'name': 'varanasi', 'registeredUsers': 524667}
# {'name': 'kanpur nagar', 'registeredUsers': 511583}
# {'name': 'agra', 'registeredUsers': 392222}
# {'name': 'gorakhpur', 'registeredUsers': 336196}
# {'name': 'meerut', 'registeredUsers': 311930}
# {'name': 'bareilly', 'registeredUsers': 279714}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1282816}
# {'name': 'lucknow', 'registeredUsers': 1011470}
# {'name': 'ghaziabad', 'registeredUsers': 975605}
# {'name': 'prayagraj', 'registeredUsers': 602739}
# {'name': 'kanpur nagar', 'registeredUsers': 585796}
# {'name': 'varanasi', 'registeredUsers': 583444}
# {'name': 'agra', 'registeredUsers': 461224}
# {'name': 'gorakhpur', 'registeredUsers': 387961}
# {'name': 'meerut', 'registeredUsers': 361091}
# {'name': 'bareilly', 'registeredUsers': 318597}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1415905}
# {'name': 'lucknow', 'registeredUsers': 1124832}
# {'name': 'ghaziabad', 'registeredUsers': 1088568}
# {'name': 'prayagraj', 'registeredUsers': 667277}
# {'name': 'kanpur nagar', 'registeredUsers': 655175}
# {'name': 'varanasi', 'registeredUsers': 639586}
# {'name': 'agra', 'registeredUsers': 530228}
# {'name': 'gorakhpur', 'registeredUsers': 434172}
# {'name': 'meerut', 'registeredUsers': 408972}
# {'name': 'bareilly', 'registeredUsers': 356146}
# {'name': 'gautam buddha nagar', 'registeredUsers': 1537791}
# {'name': 'lucknow', 'registeredUsers': 1221681}
# {'name': 'ghaziabad', 'registeredUsers': 1189357}
# {'name': 'prayagraj', 'registeredUsers': 738307}
# {'name': 'kanpur nagar', 'registeredUsers': 718251}
# {'name': 'varanasi', 'registeredUsers': 706509}
# {'name': 'agra', 'registeredUsers': 593453}
# {'name': 'gorakhpur', 'registeredUsers': 483523}
# {'name': 'meerut', 'registeredUsers': 455353}
# {'name': 'bareilly', 'registeredUsers': 398897}
# {'name': 'gautam buddha nagar', 'registeredUsers': 3965080}
# {'name': 'lucknow', 'registeredUsers': 3309599}
# {'name': 'ghaziabad', 'registeredUsers': 3240845}
# {'name': 'prayagraj', 'registeredUsers': 2163437}
# {'name': 'kanpur nagar', 'registeredUsers': 2038863}
# {'name': 'varanasi', 'registeredUsers': 2000419}
# {'name': 'agra', 'registeredUsers': 1827812}
# {'name': 'gorakhpur', 'registeredUsers': 1482201}
# {'name': 'meerut', 'registeredUsers': 1369150}
# {'name': 'bareilly', 'registeredUsers': 1256323}
# {'name': 'gautam buddha nagar', 'registeredUsers': 4112477}
# {'name': 'lucknow', 'registeredUsers': 3433006}
# {'name': 'ghaziabad', 'registeredUsers': 3364054}
# {'name': 'prayagraj', 'registeredUsers': 2246704}
# {'name': 'kanpur nagar', 'registeredUsers': 2116734}
# {'name': 'varanasi', 'registeredUsers': 2075958}
# {'name': 'agra', 'registeredUsers': 1897322}
# {'name': 'gorakhpur', 'registeredUsers': 1541095}
# {'name': 'meerut', 'registeredUsers': 1420863}
# {'name': 'bareilly', 'registeredUsers': 1304230}
# {'name': 'gautambuddha nagar', 'registeredUsers': 4449683}
# {'name': 'lucknow', 'registeredUsers': 3565800}
# {'name': 'ghaziabad', 'registeredUsers': 3496832}
# {'name': 'prayagraj', 'registeredUsers': 2284614}
# {'name': 'agra', 'registeredUsers': 2103223}
# {'name': 'kanpur nagar', 'registeredUsers': 2099245}
# {'name': 'varanasi', 'registeredUsers': 2027531}
# {'name': 'gorakhpur', 'registeredUsers': 1685478}
# {'name': 'meerut', 'registeredUsers': 1591722}
# {'name': 'bareilly', 'registeredUsers': 1513919}
# {'name': 'gautambuddha nagar', 'registeredUsers': 4577065}
# {'name': 'lucknow', 'registeredUsers': 3675410}
# {'name': 'ghaziabad', 'registeredUsers': 3585148}
# {'name': 'prayagraj', 'registeredUsers': 2366419}
# {'name': 'agra', 'registeredUsers': 2177829}
# {'name': 'kanpur nagar', 'registeredUsers': 2169076}
# {'name': 'varanasi', 'registeredUsers': 2093895}
# {'name': 'gorakhpur', 'registeredUsers': 1752309}
# {'name': 'meerut', 'registeredUsers': 1641966}
# {'name': 'bareilly', 'registeredUsers': 1565625}
